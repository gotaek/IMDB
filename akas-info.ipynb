# %%
import csv
import pymysql

# %%
f = open('title.akas.tsv', 'r', encoding='utf=8')
rd = csv.reader(f, delimiter='\t')

conn=pymysql.connect(host='localhost',user='gotaek',password='gotaek',db='IMDB')
curs=conn.cursor(pymysql.cursors.DictCursor)

sql="insert ignore into akas_types(workId,ordering,akasType)values(%s,%s,%s)"

next(rd)

for line in rd:
    if line[5]!='\\N':
        for i in line[5].split(','):
            data=(line[0],line[1],i)
            print(line[0])
            curs.execute(sql,data)
            conn.commit()
    
    

curs.close()
conn.close()
f.close()
# Out:
# ('tt0000069', '2', 'imdbDisplay')
# ('tt0000069', '3', '\\N')
# ('tt0000069', '4', 'imdbDisplay')
# ('tt0000069', '5', 'original')
# ('tt0000069', '6', '\\N')
# ('tt0000070', '10', 'imdbDisplay')
# ('tt0000070', '11', 'imdbDisplay')
# ('tt0000070', '12', 'original')
# ('tt0000070', '13', '\\N')
# ('tt0000070', '14', '\\N')
# ('tt0000070', '15', 'imdbDisplay')
# ('tt0000070', '1', 'imdbDisplay')
# ('tt0000070', '2', '\\N')
# ('tt0000070', '3', '\\N')
# ('tt0000070', '4', 'imdbDisplay')
# ('tt0000070', '5', '\\N')
# ('tt0000070', '6', '\\N')
# ('tt0000070', '7', 'imdbDisplay')
# ('tt0000070', '8', 'imdbDisplay')
# ('tt0000070', '9', '\\N')
# ('tt0000071', '1', 'imdbDisplay')
# ('tt0000071', '2', '\\N')
# ('tt0000071', '3', 'original')
# ('tt0000072', '1', 'imdbDisplay')
# ('tt0000072', '2', 'original')
# ('tt0000072', '3', '\\N')
# ('tt0000073', '1', 'original')
# ('tt0000073', '2', '\\N')
# ('tt0000073', '3', 'imdbDisplay')
# ('tt0000074', '1', 'imdbDisplay')
# ...

# %%
f = open('title.akas.tsv', 'r', encoding='utf=8')
rd = csv.reader(f, delimiter='\t')

conn=pymysql.connect(host='localhost',user='gotaek',password='gotaek',db='IMDB')
curs=conn.cursor(pymysql.cursors.DictCursor)

sql="insert ignore into akas_attributes(workId,ordering,akasAttributes)values(%s,%s,%s)"

next(rd)
for line in rd:
    if line[6]!="\\N":
        for i in line[6].split(','):
            data=(line[0],line[1],i)
            print(line[0])
            curs.execute(sql,data)
            conn.commit()
   
    

curs.close()
conn.close()
f.close()
# Out:
# ('tt0000001', '1', '\\N')
# ('tt0000001', '2', 'literal title')
# ('tt0000001', '3', '\\N')
# ('tt0000001', '4', '\\N')
# ('tt0000001', '5', '\\N')
# ('tt0000001', '6', '\\N')
# ('tt0000001', '7', '\\N')
# ('tt0000001', '8', '\\N')
# ('tt0000002', '1', '\\N')
# ('tt0000002', '2', '\\N')
# ('tt0000002', '3', '\\N')
# ('tt0000002', '4', 'literal title')
# ('tt0000002', '5', '\\N')
# ('tt0000002', '6', '\\N')
# ('tt0000002', '7', 'literal English title')
# ('tt0000002', '8', '\\N')
# ('tt0000003', '1', '\\N')
# ('tt0000003', '2', '\\N')
# ('tt0000003', '3', '\\N')
# ('tt0000003', '4', '\\N')
# ('tt0000003', '5', '\\N')
# ('tt0000003', '6', '\\N')
# ('tt0000003', '7', '\\N')
# ('tt0000003', '8', '\\N')
# ('tt0000003', '9', 'literal title')
# ('tt0000004', '1', '\\N')
# ('tt0000004', '2', 'literal title')
# ('tt0000004', '3', '\\N')
# ('tt0000004', '4', '\\N')
# ('tt0000004', '5', '\\N')
# ('tt0000004', '6', '\\N')
# ('tt0000004', '7', '\\N')
# ('tt0000004', '8', '\\N')
# ...
