# %%
import csv
import pymysql

# %%
f = open('title.episode.tsv', 'r', encoding='utf=8')
rd = csv.reader(f, delimiter='\t')

conn=pymysql.connect(host='localhost',user='gotaek',password='gotaek',db='IMDB')
curs=conn.cursor(pymysql.cursors.DictCursor)

sql="insert ignore into episode(episodeId,parentWorkId,seasonNumber,episodeNumber)values(%s,%s,%s,%s)"

next(rd)

for line in rd:
    if()
    data=(line[0],line[1],line[2],line[3])
    print(data)

    curs.execute(sql,data)
    conn.commit()
    

curs.close()
conn.close()
f.close()
# Out:
# 12699', '5', '2')
# ('tt0064367', 'tt0058836', '3', '13')
# ('tt0064404', 'tt0058853', '1', '153')
# ('tt0064412', 'tt0165593', '5', '1')
# ('tt0064444', 'tt0212699', '4', '25')
# ('tt0064468', 'tt0165593', '4', '9')
# ('tt0064475', 'tt0065303', '1', '0')
# ('tt0064502', 'tt0058853', '1', '158')
# ('tt0064525', 'tt0165593', '4', '8')
# ('tt0064584', 'tt0958966', '1', '4')
# ('tt0064600', 'tt0958966', '1', '8')
# ('tt0064636', 'tt0063927', '1', '0')
# ('tt0064648', 'tt0065317', '1', '0')
# ('tt0064657', 'tt1601979', '1', '5')
# ('tt0064678', 'tt10524910', '\\N', '\\N')
# ('tt0064692', 'tt0297621', '1', '15')
# ('tt0064700', 'tt0958966', '1', '11')
# ('tt0064705', 'tt0046593', '16', '2')
# ('tt0064725', 'tt0065327', '1', '0')
# ('tt0064830', 'tt0398430', '3', '2')
# ('tt0064901', 'tt0212699', '4', '34')
# ('tt0064903', 'tt0212699', '4', '26')
# ('tt0064922', 'tt0297621', '1', '30')
# ('tt0064942', 'tt1601979', '1', '4')
# ('tt0064998', 'tt0058853', '1', '142')
# ...
