# %%
import pymysql
import csv

# %%
f = open('name.basics.tsv', 'r', encoding='utf=8')
rd = csv.reader(f, delimiter='\t')

conn=pymysql.connect(host='localhost',user='gotaek',password='gotaek',db='IMDB')
curs=conn.cursor(pymysql.cursors.DictCursor)

sql="insert ignore into actor (actorId,primaryName,birthYear,deathYear) values(%s,%s,%s,%s)"
next(rd)
for line in rd:
    
    if "actor" in line[4] or "actress" in line[4]:
        a=line[2] if line[2]!="\\N" else "0"
        b=line[3] if line[3] !="\\N" else "0"
        data=(line[0],line[1],a,b)
    
        print(data)
        curs.execute(sql,data)
        conn.commit()

f.close()
# Out:
# 050809', 'Tatiana Ballesteros', '0', '0')
# ('nm0050810', 'Toña Ballesteros', '0', '0')
# ('nm0050814', 'Bernard Ballet', '0', '0')
# ('nm0050815', 'Marta Balletbò-Coll', '1960', '0')
# ('nm0050816', 'Francesca Balletta', '0', '0')
# ('nm0050822', 'Elaina Ballew', '1964', '0')
# ('nm0050823', 'J. Lee Ballew', '0', '0')
# ('nm0050825', 'Michael Ballew', '0', '0')
# ('nm0050827', 'Smith Ballew', '1902', '1984')
# ('nm0050829', 'Brigitte Balleys', '0', '0')
# ('nm0050830', 'Carl Balhaus', '1905', '1968')
# ('nm0050833', 'Helga Ballhaus', '1935', '2006')
# ('nm0050836', 'Sean Ballhorn', '0', '0')
# ('nm0050837', 'Rudy Balli', '1970', '0')
# ('nm0050838', 'Umberto Balli', '0', '0')
# ('nm0050839', 'W. Ballie', '0', '0')
# ('nm0050840', 'Günther Ballier', '1900', '1980')
# ('nm0050842', 'Marc Ballif', '0', '0')
# ('nm0050843', 'Woon-Ngor Ballik', '0', '0')
# ('nm0050845', 'Günther Ballin', '0', '0')
# ('nm0050848', 'Jesse Ballin', '0', '0')
# ('nm0050849', 'Mabel Ballin', '1887', '1958')
# ('nm0050851', 'Patrick Ballin', '0', '0')
# ('nm0050854', 'Henrik Balling', '0', '0')
# ('nm0050857', 'Sara Ballingall', '1972', '0')
# ('nm0050860', 'Charles Ballinger', '0', '0')
# ('nm0050861', 'Charlotte H. Ballinger', '0', '0')
# ('nm0050862', 'Christopher Ballinger', '0', '0')
# ('nm0050863', 'Chuck Ballinger', '0', '0')
# ('nm0050864', 'Don Ballinger', '0', '0')
# ('nm0050865', 'Irene Ballinger', '0', '0')
# ('nm0050871', 'Terrance Ballinger', '0', '0')
# ('nm0050874', 'Bill Ballis', '0', '0')
# ('nm0050875', 'Socrates Ballis', '1933', '1998')
# ('nm0050876', 'Gigi Ballista', '1918', '1980')
# ('nm0050877', 'Dieter Ballmann', '0', '0')
# ('nm0050878', 'Hans-Jürgen Ballmann', '0', '0')
# ('nm0050881', 'Matthias Ballmann', '1975', '0')
# ('nm0050883', 'Steve Ballmer', '1956', '0')
# ('nm0050889', 'Nick Ballo', '0', '0')
# ('nm0050891', 'Sergio Ballo', '0', '0')
# ('nm0050892', 'Tone Ballo', '0', '0')
# ('nm0050894', 'Paulette Ballock', '0', '0')
# ('nm0050895', 'Edward Ballog', '0', '0')
# ('nm0050899', 'Otto Ballon', '1912', '1981')
# ('nm0050902', 'Bruno Ballone', '0', '0')
# ('nm0050904', 'Patrizia La Fonte', '1956', '0')
# ('nm0050905', 'Julie Balloo', '0', '0')
# ('nm0050906', 'Amy Ballor', '0', '0')
# ('nm0050908', 'Greg Ballora', '1964', '0')
# ('nm0050909', 'Rosa Ballorá', '0', '0')
# ('nm0050910', 'D. Ballos', '0', '0')
# ('nm0050912', 'Valentina Ballos', '0', '0')
# ('nm0050913', 'Nadine Ballot', '0', '0')
# ('nm0050914', 'Steve Ballot', '0', '0')
# ('nm0050921', 'Howard Ballou', '0', '0')
# ('nm0050922', 'Leslie Ballou', '0', '0')
# ('nm0050923', 'Marion Ballou', '1870', '1939')
# ('nm0050924', 'Mark Ballou', '1971', '0')
# ('nm0050926', 'Phil Ballou', '0', '0')
# ('nm0050929', 'Jill Balloun', '0', '0')
# ('nm0050932', 'Lizzi Ballox', '0', '0')
# ('nm0050935', 'German Ballsteron', '0', '0')
# ('nm0050936', 'Gerhard Balluch', '1942', '0')
# ('nm0050943', 'George Bally', '0', '0')
# ('nm0050944', 'Ilse Bally', '1914', '2007')
# ('nm0050951', 'Jean-François Ballèvre', '0', '0')
# ('nm0050953', 'Karyn Balm', '1939', '1980')
# ('nm0050954', 'Roger Balm', '0', '0')
# ('nm0050955', 'John Balma', '1959', '0')
# ('nm0050957', 'Jorge Balmaceda', '0', '0')
# ('nm0050958', 'Madeline Balmaceda', '1958', '0')
# ('nm0050959', 'Pedro Pascal', '1975', '0')
# ('nm0050962', 'Simone Balmaine', '0', '0')
# ('nm0050964', 'Giancarlo Balmas', '0', '0')
# ('nm0050966', 'Mario Balmaseda', '1941', '0')
# ('nm0050967', 'Simone Balmaseda', '0', '0')
# ('nm0050969', 'Valérie Balmayer', '0', '0')
# ('nm0050970', 'Maria Balmayor', '0', '0')
# ('nm0050971', 'C. Balme', '0', '0')
# ('nm0050975', 'Timothy Balme', '0', '0')
# ('nm0050976', 'Véronique Balme', '0', '0')
# ('nm0050977', 'Clarence Balmer', '1929', '1997')
# ('nm0050978', 'Dagmar Balmer', '0', '0')
# ('nm0050979', 'Don Balmer', '1937', '0')
# ('nm0050980', 'Norman Balmer', '0', '0')
# ('nm0050983', 'Jean-François Balmer', '1946', '0')
# ('nm0050984', 'Lucy Balmer', '0', '0')
# ('nm0050986', 'Werner Balmer', '0', '0')
# ('nm0050987', 'José Balmes', '1927', '0')
# ('nm0050989', 'Clare Balmford', '0', '0')
# ('nm0050990', 'Andrew Balmforth', '0', '0')
# ('nm0050993', 'Tom Balmos', '0', '0')
# ('nm0050994', 'Yulyen Balmusov', '1940', '2020')
# ('nm0051003', 'Ilze Balodis', '0', '0')
# ('nm0051007', 'Imre Töró Balog', '0', '0')
# ('nm0051008', 'Jozsef Balog', '0', '0')
# ('nm0051009', 'Judit Balog', '1953', '0')
# ('nm0051010', 'Lajos Balog', '0', '0')
# ('nm0051011', 'Marian Balog', '0', '0')
# ('nm0051015', 'Mike Balog', '0', '0')
# ('nm0051016', 'Vid Balog', '1972', '0')
# ('nm0051017', 'Zoltán Balog', '0', '0')
# ('nm0051018', 'Bob Balogh', '1950', '0')
# ('nm0051020', 'Csilla Balogh', '1962', '0')
# ('nm0051022', 'Elizabeth Balogh', '0', '0')
# ('nm0051023', 'Emese Balogh', '1939', '2014')
# ('nm0051024', 'Erika Balogh', '1958', '0')
# ('nm0051026', 'Erzsi Balogh', '1922', '2008')
# ('nm0051028', 'Gyula Balogh', '0', '0')
# ('nm0051031', 'György Balogh', '0', '0')
# ('nm0051033', 'István Balogh', '1902', '1994')
# ('nm0051036', 'Joe Balogh', '0', '0')
# ('nm0051037', 'Julia Balogh', '0', '0')
# ('nm0051038', 'Julianna Balogh', '0', '0')
# ('nm0051039', 'Klári Balogh', '1913', '1999')
# ('nm0051041', 'László Váradi Balogh', '1916', '0')
# ('nm0051044', 'László Balogh', '0', '0')
# ('nm0051045', 'Mari Balogh', '0', '0')
# ('nm0051046', 'Menyhért René Balog-Dutombé', '0', '0')
# ('nm0051048', 'Nina Balogh', '0', '0')
# ('nm0051049', 'Péter Balogh', '0', '0')
# ('nm0051050', 'Rudolf Balogh', '0', '0')
# ('nm0051051', 'Steve Balogh', '0', '0')
# ('nm0051052', 'Tamás Balogh', '1944', '2019')
# ('nm0051053', 'Teri Balogh', '0', '0')
# ('nm0051055', 'Zsuzsa Balogh', '1943', '0')
# ('nm0051058', 'Abdul-Fatai Balogun', '0', '0')
# ('nm0051059', 'Ola Balogun', '1945', '0')
# ('nm0051060', 'Miha Baloh', '1928', '0')
# ('nm0051061', 'Lucas Baloyi', '0', '0')
# ('nm0051063', 'Costel Baloiu', '1959', '0')
# ('nm0051064', 'Wendy Balomben', '0', '0')
# ('nm0051068', 'Maja Balon', '0', '0')
# ('nm0051069', 'Vladimir Balon', '1937', '2013')
# ('nm0051071', 'Paulo Balonas', '0', '0')
# ('nm0051073', 'Rowena Balos', '0', '0')
# ('nm0051074', 'Buddy Balou', '1953', '0')
# ('nm0051076', 'Ales Baloun', '0', '0')
# ('nm0051078', 'Dana Balounová', '1935', '1985')
# ('nm0051079', 'Ladislav Balous', '0', '0')
# ('nm0051082', 'Bruno Balp', '1926', '2008')
# ('nm0051083', 'Jérôme Balp', '0', '0')
# ('nm0051084', 'Ruth Balpiyangay', '0', '0')
# ('nm0051085', 'Robert Balpo', '0', '0')
# ('nm0051086', 'Antoine Balpêtré', '1898', '1963')
# ('nm0051088', 'Erica Balqué', '1912', '2003')
# ('nm0051090', 'Maria Balra', '0', '0')
# ('nm0051091', 'Anand Balraj', '0', '0')
# ('nm0051092', 'Balram', '0', '0')
# ('nm0051095', 'José Balsalobre', '0', '0')
# ('nm0051097', 'Bert F. Balsam', '1923', '2003')
# ('nm0051101', 'James Balsam', '0', '0')
# ('nm0051104', 'Talia Balsam', '1959', '0')
# ('nm0051106', 'Ivan Balsamadzhiev', '1953', '2010')
# ('nm0051107', 'Albert Balsamo', '0', '0')
# ('nm0051108', 'Eduardo Balsamo', '0', '0')
# ('nm0051110', 'Ignazio Balsamo', '1912', '1994')
# ('nm0051111', 'Jean Balsamo', '0', '0')
# ('nm0051112', 'Raffaele Balsamo', '0', '0')
# ('nm0051113', 'Vito Balsamo', '0', '0')
# ('nm0051114', 'Jesus Balsamà', '1988', '0')
# ('nm0051115', 'Charles Balsan', '0', '0')
# ('nm0051116', 'Humbert Balsan', '1954', '2005')
# ('nm0051117', 'Louise Balsan', '0', '0')
# ('nm0051120', 'Dale Balsbaugh', '0', '0')
# ('nm0051121', 'Richie Balsbaugh', '0', '0')
# ('nm0051122', 'Janos Balczik', '1974', '0')
# ('nm0051124', 'Pilar Balsega', '0', '0')
# ('nm0051125', 'Mendonça Balsemão', '0', '0')
# ('nm0051127', 'Cima Balser', '1929', '2019')
# ('nm0051129', 'David Balser', '0', '0')
# ('nm0051130', 'Dean Balser', '0', '0')
# ('nm0051131', 'Evelyn Balser', '0', '0')
# ('nm0051132', 'Ewald Balser', '1898', '1978')
# ('nm0051136', 'Vera Balser-Eberle', '1897', '1982')
# ('nm0051137', 'Anderson Balsero', '0', '0')
# ('nm0051145', 'Eric Balsim', '0', '0')
# ('nm0051146', 'Jeanette Balsis', '0', '0')
# ('nm0051147', 'Ilona Balsyte', '0', '0')
# ('nm0051148', 'Laust Balskov', '0', '0')
# ('nm0051149', 'Lisbeth Balslev', '1945', '0')
# ('nm0051152', 'Tom Balsley Jr.', '0', '0')
# ('nm0051159', 'Allison Balson', '1969', '0')
# ('nm0051161', 'Sandy Balson', '1930', '2015')
# ('nm0051162', 'Dunca Balsor', '0', '0')
# ('nm0051163', 'Emmanuel Balssa', '0', '0')
# ('nm0051164', 'Michael Balston', '0', '0')
# ('nm0051165', 'Irini Balta', '0', '0')
# ('nm0051169', 'José Luis Baltanás', '0', '0')
# ('nm0051170', 'Ángel María Baltanás', '1929', '1979')
# ('nm0051171', 'Claudio Baltar', '0', '0')
# ('nm0051173', 'Constantin Baltaretu', '1938', '1985')
# ('nm0051178', 'Iulian Baltatescu', '0', '0')
# ('nm0051179', 'Christian Baltauss', '0', '0')
# ('nm0051180', 'Julie Baltay', '0', '0')
# ('nm0051182', 'Manuelle Baltazar', '0', '0')
# ('nm0051183', 'Mark Baltazar', '0', '0')
# ('nm0051185', 'Raymundo Baltazar', '1981', '0')
# ('nm0051187', 'Irina Baltcheva', '0', '0')
# ('nm0051188', 'Beba Balteano', '0', '0')
# ('nm0051192', 'Jean-Philippe Baltel', '0', '0')
# ('nm0051193', 'Alla Balter', '1940', '2000')
# ('nm0051196', 'James Balter', '0', '0')
# ('nm0051197', 'Margie Balter', '1950', '2017')
# ('nm0051199', 'Sam Balter', '1909', '1998')
# ('nm0051200', 'Sheila Balter', '0', '0')
# ('nm0051201', 'Jameson Baltes', '0', '0')
# ('nm0051202', 'John Baltes', '1933', '2020')
# ('nm0051203', 'Terren Baltes', '0', '0')
# ('nm0051205', 'Jean Balthasar', '1920', '0')
# ('nm0051206', 'Nic Balthazar', '1964', '0')
# ('nm0051208', 'Harrison Balthaser', '0', '0')
# ('nm0051209', 'Jimmie Lee Balthazar', '0', '0')
# ('nm0051211', 'Max-Edouard Balthazard', '0', '0')
# ('nm0051214', 'Alfred Balthoff', '1905', '1989')
# ('nm0051215', 'Charlotte Balthorpe', '0', '0')
# ('nm0051216', 'Denise Balthrop', '0', '0')
# ('nm0051218', 'Balthus', '1908', '2001')
# ('nm0051224', 'Charli Baltimore', '1974', '0')
# ('nm0051226', 'Jacques Baltimore', '0', '0')
# ('nm0051229', 'Vicki Baltimore', '0', '0')
# ('nm0051230', 'Ken Baltin', '0', '0')
# ('nm0051232', 'Deena Baltman', '0', '0')
# ('nm0051233', 'Erika Baltodano', '0', '0')
# ('nm0051236', 'Carl Balton', '0', '0')
# ('nm0051237', 'Donna Baltron', '0', '0')
# ('nm0051248', 'Avgust Baltrusaitis', '1937', '2015')
# ('nm0051251', 'Agnes Baltsa', '1944', '0')
# ('nm0051253', 'Gerd Baltus', '1932', '2019')
# ('nm0051254', 'Louis Baltus', '0', '0')
# ('nm0051255', 'Tatyana Baltushevich', '0', '0')
# ('nm0051256', 'Florence Baltz', '0', '0')
# ('nm0051257', 'Kirk Baltz', '1959', '0')
# ('nm0051259', 'Deborah Baltzell', '1955', '1981')
# ('nm0051262', 'Jonathan Baltzer', '0', '0')
# ('nm0051265', 'Tove Baltzersen', '0', '0')
# ('nm0051266', 'Daniel Baltzman', '0', '0')
# ('nm0051267', 'Balu', '0', '0')
# ('nm0051270', 'Gayathri Balu', '0', '0')
# ('nm0051272', 'Lita Baluarte', '0', '0')
# ('nm0051278', 'Chantal Balussou', '0', '0')
# ('nm0051279', 'Liz Balut', '0', '0')
# ('nm0051281', 'Jacques Balutin', '1936', '0')
# ('nm0051282', 'Aleksandr Baluev', '1958', '0')
# ('nm0051283', 'Yelena Baluyeva', '0', '0')
# ('nm0051287', 'Ángeles Balvanera', '0', '0')
# ('nm0051289', 'Linda Maria Balver', '0', '0')
# ('nm0051290', 'Vincent Balvet', '0', '0')
# ('nm0051294', 'Saundra Baly', '0', '0')
# ('nm0051295', 'Tamara Balyan', '0', '0')
# ('nm0051296', 'Vladimir Balybin', '0', '0')
# ('nm0051297', 'Claude Blayn', '0', '0')
# ('nm0051299', 'O. Balyuv', '0', '0')
# ('nm0051302', 'Haydée Balza', '1948', '0')
# ('nm0051305', 'Jeanne de Balzac', '1891', '1930')
# ('nm0051306', 'William Balzac', '0', '0')
# ('nm0051309', 'Nelly Kafsky', '0', '0')
# ('nm0051310', 'Ninon Balzan', '0', '0')
# ('nm0051311', 'Odetta Balzan', '0', '0')
# ('nm0051312', 'Romolo Balzani', '1892', '1962')
# ('nm0051313', 'Flora Balzano', '0', '0')
# ('nm0051315', 'Daniela Balzaretti', '0', '0')
# ('nm0051316', 'Fernando Balzaretti', '1946', '1998')
# ('nm0051318', 'Jorge Balzaretti', '0', '0')
# ('nm0051319', 'Lucila Balzaretti', '0', '0')
# ('nm0051320', 'Andrew Balzarini', '0', '0')
# ('nm0051322', 'Manuel Balzarini', '0', '0')
# ('nm0051326', 'Walter Balzarini', '1936', '2011')
# ('nm0051327', 'Jorge Balzarte', '0', '0')
# ('nm0051330', 'Catherine M. Balzer', '0', '0')
# ('nm0051332', 'George Balzer', '1915', '2006')
# ('nm0051334', 'Heike Balzer', '0', '0')
# ('nm0051337', 'Karl Michael Balzer', '1944', '2014')
# ('nm0051338', 'Robert L. Balzer', '1912', '2011')
# ('nm0051345', 'Eliska Balzerová', '1949', '0')
# ('nm0051346', 'Ernesto Balzi', '0', '0')
# ('nm0051351', 'Carlos Balá', '1925', '0')
# ('nm0051352', 'Margit Balák', '0', '0')
# ('nm0051355', 'Ferenc Balázs', '1951', '2020')
# ('nm0051358', 'István Balázs', '1902', '1976')
# ('nm0051359', 'János Balázs', '1910', '1983')
# ('nm0051362', 'Péter Balázs', '1943', '0')
# ('nm0051363', 'Samu Balázs', '1906', '1981')
# ('nm0051365', 'Lajos Balázsovits', '1946', '0')
# ('nm0051366', 'Panna Balázsy', '1967', '0')
# ('nm0051368', 'Bernadett Baló', '0', '0')
# ('nm0051369', 'Elemér Baló', '1892', '1970')
# ('nm0051370', 'Júlia Baló', '1952', '0')
# ('nm0051371', 'Sándor Baló', '0', '0')
# ('nm0051372', 'Bam', '1974', '0')
# ('nm0051377', 'Martha Bamattre', '1891', '1970')
# ('nm0051379', 'Désiré Bamba', '0', '0')
# ('nm0051380', 'Kramoko Bamba', '0', '0')
# ('nm0051381', 'Mamary Bamba', '0', '0')
# ('nm0051382', 'Afrika Bambaataa', '1957', '0')
# ('nm0051384', 'Josef Bambach', '1906', '1997')
# ('nm0051386', 'Ionela Bambaloi', '0', '0')
# ('nm0051387', 'Toni Cade Bambara', '1939', '1995')
# ('nm0051390', 'Daniela Bambasová', '1954', '0')
# ('nm0051394', 'David Bamber', '1954', '0')
# ('nm0051397', 'Jamie Bamber', '1973', '0')
# ('nm0051398', 'Judy Bamber', '1936', '0')
# ('nm0051399', 'Peter Bamber', '0', '0')
# ('nm0051401', 'Sharon Bamber', '0', '0')
# ('nm0051402', 'Sharyn Bamber', '0', '0')
# ('nm0051404', 'David T. Bamberg', '1904', '1974')
# ('nm0051405', 'Florian Bamberg', '1982', '0')
# ('nm0051407', 'Walter Bamberg', '0', '0')
# ('nm0051408', 'Piet Bambergen', '1931', '1996')
# ('nm0051414', 'Hilary Bamberger', '1936', '0')
# ('nm0051416', 'Jan Bamberger', '0', '0')
# ('nm0051417', 'Jean-Pierre Bamberger', '1926', '2014')
# ('nm0051423', 'Lee Jay Bamberry', '0', '0')
# ('nm0051424', 'Tammy', '0', '0')
# ('nm0051425', 'Bambi', '1967', '0')
# ('nm0051426', 'Bambi', '1972', '0')
# ('nm0051428', 'Pair Bambi', '0', '0')
# ('nm0051429', 'Saverio Bambi', '0', '0')
# ('nm0051432', 'Ernesto Bambini', '0', '0')
# ('nm0051433', 'Stefano Bambini', '0', '0')
# ('nm0051434', 'Bambino', '1943', '1999')
# ('nm0051436', 'Nadia Bambirra', '0', '0')
# ('nm0051437', 'Christina Bambo', '0', '0')
# ('nm0051438', 'Dana Bambo', '0', '0')
# ('nm0051439', 'Bamboo', '1974', '0')
# ('nm0051443', 'Elsie Bambrick', '0', '0')
# ('nm0051444', 'Emma Bambrick', '0', '0')
# ('nm0051445', 'Gertrude Bambrick', '1893', '1974')
# ('nm0051446', 'Ben Bambridge', '0', '0')
# ('nm0051447', 'Bill Bambridge', '1892', '1950')
# ('nm0051453', 'John T. Bambury', '1891', '1960')
# ('nm0051454', 'Vyacheslav Bambushek', '0', '0')
# ('nm0051455', 'George Bamby', '1921', '1993')
# ('nm0051456', 'Edda Bamdas', '1900', '1987')
# ('nm0051457', 'Jean-Marc Bamdiran', '0', '0')
# ('nm0051459', 'Lawrence Bame', '0', '0')
# ('nm0051461', 'Randy Bame', '0', '0')
# ('nm0051462', 'Ernst Bamert', '1972', '0')
# ('nm0051463', 'David Bamford', '0', '0')
# ('nm0051464', 'Freda Bamford', '1909', '1986')
# ('nm0051465', 'George Bamford', '1944', '0')
# ('nm0051466', 'James Bamford', '1967', '0')
# ('nm0051467', 'Joan Bamford', '0', '0')
# ('nm0051468', 'Johnny Bamford', '0', '0')
# ('nm0051469', 'Maria Bamford', '1970', '0')
# ('nm0051471', 'Roger Bamford', '0', '0')
# ('nm0051472', 'Simon Bamford', '0', '0')
# ('nm0051473', 'Harold E. Bamford', '0', '0')
# ('nm0051475', 'Dawn Bamforth', '0', '0')
# ('nm0051476', 'Erica Bamforth', '0', '0')
# ('nm0051477', 'Arturo Bamio', '0', '0')
# ('nm0051478', 'Francisca Bamishe', '0', '0')
# ('nm0051479', 'Firdous Bamji', '1966', '0')
# ('nm0051480', 'Peter Bamler', '1964', '0')
# ('nm0051482', 'Gerry Bamman', '1941', '0')
# ('nm0051483', 'Gerry Bammem', '0', '0')
# ('nm0051484', 'Helga Bammert', '0', '0')
# ('nm0051486', 'Hassan Bamohamed', '0', '0')
# ('nm0051487', 'Corneille Bamombi', '0', '0')
# ('nm0051488', 'Jose Bamonde', '0', '0')
# ('nm0051492', 'Carine Bamps', '0', '0')
# ('nm0051494', 'Erick Bamy', '1949', '2014')
# ('nm0051495', 'Maddly Bamy', '1943', '0')
# ('nm0051496', 'Andreas Ban', '1973', '0')
# ('nm0051499', 'Daisuke Ban', '1947', '0')
# ('nm0051500', 'Ivo Ban', '1949', '0')
# ('nm0051501', 'Joan Ban', '0', '0')
# ('nm0051502', 'Junzaburô Ban', '1908', '1981')
# ('nm0051503', 'Minako Ban', '0', '0')
# ('nm0051504', 'Prosperous Ban', '0', '0')
# ('nm0051508', 'Yûtarô Ban', '0', '0')
# ('nm0051509', 'Eric Bana', '1968', '0')
# ('nm0051511', 'Manfred Banach', '1955', '0')
# ('nm0051512', 'Michal Banach', '1969', '0')
# ('nm0051514', 'Hailey Banack', '0', '0')
# ('nm0051521', 'Jordi Banacolocha', '0', '0')
# ('nm0051524', 'Chaim Banai', '1937', '2008')
# ('nm0051525', 'Ehud Banai', '1953', '0')
# ('nm0051526', 'Gavri Banai', '1940', '0')
# ('nm0051528', 'Meir Banai', '1961', '2017')
# ('nm0051529', 'Orna Banai', '1966', '0')
# ('nm0051530', 'Uri Banai', '1969', '0')
# ('nm0051531', "Ya'ackov Banai", '1919', '1993')
# ('nm0051533', 'Yossi Banai', '1932', '2006')
# ('nm0051535', 'Yuval Banai', '1962', '0')
# ('nm0051536', 'Pouri Baneai', '1940', '0')
# ('nm0051541', 'Christopher Banaman', '0', '0')
# ('nm0051542', 'Jacquie Banan', '0', '0')
# ('nm0051543', 'Joe Banana', '0', '0')
# ('nm0051544', 'Rick Banana', '0', '0')
# ('nm0051546', 'Arun Dias Banarayake', '0', '0')
# ('nm0051547', 'Eduard Banarescu', '0', '0')
# ('nm0051548', 'Orna Banarie', '0', '0')
# ('nm0051549', 'Alexis Banas', '0', '0')
# ('nm0051550', 'Arlene Banas', '1946', '0')
# ('nm0051551', 'Robert Banas', '1933', '0')
# ('nm0051552', 'Carl Banas', '1929', '0')
# ('nm0051557', 'Leon Banas', '0', '0')
# ('nm0051558', 'Michala Banas', '1978', '0')
# ('nm0051561', 'Stanislaw Banas', '1954', '0')
# ('nm0051562', 'Lynn Banashek', '0', '0')
# ('nm0051564', 'Mieczyslaw Banasik', '1940', '0')
# ('nm0051565', 'Stanislaw Banasiuk', '1952', '0')
# ('nm0051569', 'John Banaszak', '1950', '0')
# ('nm0051571', 'Andrzej Banaszewski', '0', '0')
# ('nm0051574', 'Julia Banaszkiewicz', '0', '0')
# ('nm0051575', 'Krzysztof Banaszyk', '1970', '0')
# ('nm0051576', 'Sándor Bánáti', '1920', '0')
# ('nm0051577', 'Margarida Banazol', '0', '0')
# ('nm0051578', 'Hirofumi Banba', '1950', '0')
# ('nm0051579', 'A. Banbasi', '0', '0')
# ('nm0051580', 'Frith Banbury', '1912', '2008')
# ('nm0051582', 'Kent Banbury', '0', '0')
# ('nm0051583', 'Jeanne Banc', '0', '0')
# ('nm0051585', 'Jennifer Bancale', '1970', '0')
# ('nm0051588', 'Alexandre Bancel', '0', '0')
# ('nm0051589', 'Joshua Bancel', '0', '0')
# ('nm0051590', 'Irene Bancells', '0', '0')
# ('nm0051592', 'Ray Bancharian', '0', '0')
# ('nm0051593', 'Dave Banchek', '0', '0')
# ('nm0051597', 'Mario Banchelli', '0', '0')
# ('nm0051599', 'Rodolfo Banchelli', '0', '0')
# ('nm0051600', 'Georgi Banchev', '0', '0')
# ('nm0051603', 'Alessandro Banci', '1958', '0')
# ('nm0051604', 'Robert Banci', '0', '0')
# ('nm0051605', 'Valentina Banci', '0', '0')
# ('nm0051608', 'Christer Banck', '1935', '2001')
# ('nm0051610', 'Tristan Bancks', '1974', '0')
# ('nm0051611', 'Jennifer Banco', '0', '0')
# ('nm0051615', 'Anne Bancroft', '0', '0')
# ('nm0051618', 'Benjie Bancroft', '1919', '2007')
# ('nm0051619', 'Bob Bancroft', '0', '0')
# ('nm0051620', 'Bradford Bancroft', '0', '0')
# ('nm0051621', 'Cameron Bancroft', '1967', '0')
# ('nm0051622', 'Charles Bancroft', '1910', '1969')
# ('nm0051623', 'Clare Bancroft', '0', '0')
# ('nm0051625', 'Darren Bancroft', '1973', '0')
# ('nm0051626', 'Debbie Bancroft', '0', '0')
# ('nm0051627', 'Deborah Bancroft', '0', '0')
# ('nm0051628', 'George Bancroft', '1882', '1956')
# ('nm0051629', 'George Bancroft', '0', '0')
# ('nm0051630', 'George Bancroft', '0', '0')
# ('nm0051632', 'Georgette Bancroft', '0', '0')
# ('nm0051635', 'Jonathan Bancroft', '0', '0')
# ('nm0051637', 'Libby Bancroft', '0', '0')
# ('nm0051638', 'Mickey Bancroft', '0', '0')
# ('nm0051639', 'Miss Bancroft', '0', '0')
# ('nm0051644', 'Tracy Bancroft', '0', '0')
# ('nm0051646', 'Lesley Rae Bancs', '0', '0')
# ('nm0051647', 'Mária Bancíková', '1913', '1962')
# ('nm0051648', 'Adelina Band', '0', '0')
# ('nm0051649', 'Albert Band', '1924', '2002')
# ('nm0051650', 'Alex Band', '1981', '0')
# ('nm0051652', 'Brian Banowetz', '1967', '0')
# ('nm0051657', 'Gil Band', '0', '0')
# ('nm0051658', 'Jacquelyn Band', '0', '0')
# ('nm0051661', 'Rubber Band', '0', '0')
# ('nm0051662', 'Sylvio Band', '0', '0')
# ('nm0051664', 'Taryn Band', '1977', '0')
# ('nm0051665', 'Irma Banda', '0', '0')
# ('nm0051667', 'Mariano de la Banda', '0', '0')
# ('nm0051668', 'Nati Banda', '0', '0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-4bb21196f6c0> in <module>
#      15         print(data)
#      16         curs.execute(sql,data)
# ---> 17         conn.commit()
#      18
#      19 f.close()
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pymysql\connections.py in commit(self)
#     467         in the specification.
#     468         """
# --> 469         self._execute_command(COMMAND.COM_QUERY, "COMMIT")
#     470         self._read_ok_packet()
#     471
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pymysql\connections.py in _execute_command(self, command, sql)
#     812         prelude = struct.pack("<iB", packet_size, command)
#     813         packet = prelude + sql[: packet_size - 1]
# --> 814         self._write_bytes(packet)
#     815         if DEBUG:
#     816             dump_packet(packet)
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pymysql\connections.py in _write_bytes(self, data)
#     754         self._sock.settimeout(self._write_timeout)
#     755         try:
# --> 756             self._sock.sendall(data)
#     757         except IOError as e:
#     758             self._force_close()
#
# KeyboardInterrupt:

# %%
f = open('name.basics.tsv', 'r', encoding='utf=8')
rd = csv.reader(f, delimiter='\t')

conn=pymysql.connect(host='localhost',user='gotaek',password='gotaek',db='IMDB')
curs=conn.cursor(pymysql.cursors.DictCursor)

sql="insert ignore into director (directorId,primaryName,birthYear,deathYear) values(%s,%s,%s,%s)"
next(rd)
for line in rd:
    
    if "director" in line[4] :
        a=line[2] if line[2]!="\\N" else '0'
        b=line[3] if line[3] !="\\N" else '0'
        data=(line[0],line[1],a,b )
    
        print(data)
        curs.execute(sql,data)
        conn.commit()

f.close()
# Out:
#  Alper', '1963', '0')
# ('nm0022378', 'Jens Alpermann', '1963', '0')
# ('nm0022383', 'Kleopatra Alperova', '0', '0')
# ('nm0022385', 'Michael Alperowitz', '1965', '0')
# ('nm0022387', 'Jonathan Alpers', '1971', '0')
# ('nm0022395', 'Cali Alpert', '0', '0')
# ('nm0022406', 'Harry Alpert', '0', '0')
# ('nm0022412', 'Jon Alpert', '0', '0')
# ('nm0022422', 'Moshe Alpert', '0', '0')
# ('nm0022424', 'Sasha Alpert', '0', '0')
# ('nm0022425', 'Scooter Alpert', '0', '0')
# ('nm0022450', 'Noël Alpi', '1955', '0')
# ('nm0022458', 'Amanbek Alpiyev', '0', '0')
# ('nm0022461', 'Wendy Alport', '0', '0')
# ('nm0022485', 'Yael Alrod', '0', '0')
# ('nm0022487', 'Hilton Als', '0', '0')
# ('nm0022520', 'Gustav Alsina', '0', '0')
# ('nm0022523', 'Julio Raúl Alsina', '1883', '1944')
# ('nm0022531', 'Erik Alskog', '0', '0')
# ('nm0022540', 'Russ T. Alsobrook', '1946', '0')
# ('nm0022560', 'Marina Alstad', '0', '0')
# ('nm0022581', 'Emmett Alston', '1941', '0')
# ('nm0022584', 'Harlan Alston', '0', '0')
# ('nm0022585', 'Howard P. Alston', '1921', '0')
# ('nm0022592', 'Macky Alston', '0', '0')
# ('nm0022607', 'Carl Alstrup', '1877', '1942')
# ('nm0022611', 'Sara Alström', '1975', '0')
# ('nm0022622', 'Al Alt', '1897', '1992')
# ('nm0022625', 'Duane Alt', '0', '0')
# ('nm0022636', 'Filippo Altadonna', '0', '0')
# ('nm0022638', 'Joseph M. Altadonna', '0', '0')
# ('nm0022644', 'Fernando Altamirano', '0', '0')
# ('nm0022653', 'Stephanie Altamirano', '0', '0')
# ('nm0022656', 'Elio Altamura', '0', '0')
# ('nm0022668', 'Francesco Tullio Altan', '1942', '0')
# ('nm0022673', 'Mathilde Altaraz', '0', '0')
# ('nm0022688', 'Ernie Altbacker', '0', '0')
# ('nm0022691', 'Marcela Altberg', '0', '0')
# ('nm0022692', 'Marco Altberg', '1953', '0')
# ('nm0022696', 'José Alted', '0', '0')
# ('nm0022700', 'Parshwanath Yeshwant Altekar', '1897', '1957')
# ('nm0022708', 'Rønnaug Alten', '1910', '2001')
# ('nm0022720', 'Robert Altenburger', '0', '0')
# ('nm0022722', 'Alf Altendorf', '0', '0')
# ('nm0022732', 'Corey Hamilton Alter', '0', '0')
# ('nm0022741', 'Jeremy Alter', '0', '0')
# ('nm0022742', 'Joe Alter', '0', '0')
# ('nm0022743', 'Julie Alter', '0', '0')
# ('nm0022750', 'Paul Alter', '1922', '2011')
# ('nm0022759', 'Udo Alter', '0', '0')
# ('nm0022767', 'Idan Alterman', '1971', '0')
# ('nm0022768', 'Kent Alterman', '0', '0')
# ('nm0022783', 'Georg Althammer', '1939', '0')
# ('nm0022788', 'Paul Altheer', '1887', '1959')
# ('nm0022790', 'Michael Althen', '1962', '2011')
# ('nm0022813', 'Giulio Alti', '0', '0')
# ('nm0022825', 'Jason Altieri', '1975', '0')
# ('nm0022827', 'Kathy Altieri', '0', '0')
# ('nm0022828', 'Kevin Altieri', '0', '0')
# ('nm0022840', 'Pamela Altieri-Paterra', '0', '0')
# ('nm0022858', 'Mustafa Altioklar', '1958', '0')
# ('nm0022869', 'Michael Davis', '0', '0')
# ('nm0022880', 'Brian Altman', '0', '0')
# ('nm0022882', 'Brook Altman', '0', '0')
# ('nm0022899', 'Herbert S. Altman', '0', '0')
# ('nm0022909', 'Karin Altmann', '0', '0')
# ('nm0022910', 'Kate Altman', '0', '0')
# ('nm0022913', 'Mark A. Altman', '0', '0')
# ('nm0022918', 'Mike Altman', '1955', '0')
# ('nm0022919', 'Morey Altman', '0', '0')
# ('nm0022920', 'Natan Altman', '0', '0')
# ('nm0022921', 'Olivier Altman', '0', '0')
# ('nm0022927', 'Robert Reed Altman', '1959', '0')
# ('nm0022929', 'Sarah Altman', '0', '0')
# ('nm0022939', 'Stephen Altman', '1956', '0')
# ('nm0022942', 'Walter Altman', '1952', '0')
# ('nm0022953', 'Mike Altmann', '1937', '0')
# ('nm0022960', 'Monika Altmann', '0', '0')
# ('nm0022981', 'Manuel Altolaguirre', '1905', '1959')
# ('nm0022983', 'John L. Altom', '0', '0')
# ('nm0023003', 'John Alton', '1901', '1996')
# ('nm0023012', 'Robert Alton', '1906', '1957')
# ('nm0023017', 'Gábor Altorjay', '1946', '0')
# ('nm0023020', 'Art Altounian', '0', '0')
# ('nm0023038', 'Fernando Altschul', '1962', '0')
# ('nm0023039', 'Gil Altschul', '1921', '1982')
# ('nm0023044', 'Boris Altshuler', '1904', '1994')
# ('nm0023054', 'Leonid Altsev', '0', '0')
# ('nm0023060', 'Robert Altshuler', '0', '0')
# ('nm0023067', 'Rengin Altun', '0', '0')
# ('nm0023070', 'Asier Altuna', '1969', '0')
# ('nm0023080', 'James Altwies', '1897', '1950')
# ('nm0023092', 'Francesco Aluigi', '0', '0')
# ('nm0023101', 'Georgi Alurkov', '1926', '1989')
# ('nm0023107', 'Hermanos Alva', '0', '0')
# ('nm0023119', 'Sirus Alvand', '1951', '0')
# ('nm0023147', 'Don Alvarado', '1900', '1967')
# ('nm0023159', 'Joaquin Alvarado', '0', '0')
# ('nm0023188', 'Ramón Alvarado', '0', '0')
# ('nm0023204', 'Charles Daguerre Alvaré', '0', '0')
# ('nm0023205', 'Daniel Alvaredo', '0', '0')
# ('nm0023207', 'José Alvarenga Jr.', '0', '0')
# ('nm0023221', 'Enrique Diosdado', '1910', '1983')
# ('nm0023234', 'Andrea Alvarez', '0', '0')
# ('nm0023238', 'Anthony Alvarez', '1970', '0')
# ('nm0023241', 'Barbara Alvarez', '0', '0')
# ('nm0023247', 'Clara Álvarez', '0', '0')
# ('nm0023262', 'Gus Alvarez', '0', '0')
# ('nm0023265', 'Hélio Alvarez', '0', '0')
# ('nm0023275', 'John Alvarez', '0', '0')
# ('nm0023289', 'Louis Alvarez', '1955', '0')
# ('nm0023291', 'Luis Alvarez', '0', '0')
# ('nm0023296', 'Matias Alvarez', '0', '0')
# ('nm0023303', 'Milt Alvarez', '0', '0')
# ('nm0023316', 'Robert Alvarez', '0', '0')
# ('nm0023317', 'Robert Alvarez', '0', '0')
# ('nm0023320', 'Roger Alvarez', '0', '0')
# ('nm0023342', 'Ana Alvargonzález', '1962', '0')
# ('nm0023344', 'Romualdo Tomás Alvargonzález', '0', '0')
# ('nm0023355', 'Christian Alvart', '1974', '0')
# ('nm0023356', 'Luís Alvarães', '0', '0')
# ('nm0023361', 'Laura Alvea', '1976', '0')
# ('nm0023362', 'Miguel Alvear', '0', '0')
# ('nm0023372', 'Jan Alvermark', '0', '0')
# ('nm0023375', 'Ricardo Alventosa', '1937', '1995')
# ('nm0023378', 'Kjersti Alver', '0', '0')
# ('nm0023400', 'Luís Alves de Matos', '0', '0')
# ('nm0023401', 'Naum Alves de Souza', '1942', '2016')
# ('nm0023406', 'José Manuel Alves Pereira', '0', '0')
# ('nm0023408', 'Mario Rebehy', '0', '0')
# ('nm0023410', 'Agenor Alves', '1944', '0')
# ('nm0023425', 'Bras Alves', '0', '0')
# ('nm0023430', 'Catarina Alves', '0', '0')
# ('nm0023458', 'Giselle Alves', '0', '0')
# ('nm0023460', 'Greg Alves', '0', '0')
# ('nm0023469', 'Joe Alves', '1936', '0')
# ('nm0023478', 'João Alves', '0', '0')
# ('nm0023480', 'Justino Alves', '0', '0')
# ('nm0023481', 'Júlio Alves', '0', '0')
# ('nm0023513', 'Rai Alves', '0', '0')
# ('nm0023517', 'Ruben Alves', '0', '0')
# ('nm0023518', 'Rui Alves', '0', '0')
# ('nm0023531', 'Ulisses Alves', '0', '0')
# ('nm0023537', 'Vítor Alves', '0', '0')
# ('nm0023551', 'Abrar Alvi', '1927', '2009')
# ('nm0023553', 'Daniela Alviani', '0', '0')
# ('nm0023554', 'Maximo Giuseppe Alviani', '0', '0')
# ('nm0023559', 'Umberto Alvieri', '0', '0')
# ('nm0023582', 'Catherine Alvira', '0', '0')
# ('nm0023584', 'Pablo Alvira', '0', '0')
# ('nm0023593', 'Marcus Alvisi', '1954', '0')
# ('nm0023607', 'Austin Alward', '0', '0')
# ('nm0023617', 'Veronica Alweiss', '0', '0')
# ('nm0023626', 'Jonathan Alwyn', '1930', '0')
# ('nm0023629', 'Abdel Aziz Aly', '0', '0')
# ('nm0023630', 'Don Aly', '0', '0')
# ('nm0023631', 'Fawzy Aly', '0', '0')
# ('nm0023632', 'Gamal Aly', '0', '0')
# ('nm0023639', 'Arsevir Alyanak', '1907', '1981')
# ('nm0023664', 'Walter Alza', '0', '0')
# ('nm0023676', 'Óscar Alzate', '0', '0')
# ('nm0023681', 'Walter Alzmann', '1932', '1980')
# ('nm0023702', 'Georges Alépée', '0', '0')
# ('nm0023703', 'Christophe Alévêque', '1963', '0')
# ('nm0023713', 'John Amabile', '0', '0')
# ('nm0023720', 'Louis-Balthazar Amadangoleda', '0', '0')
# ('nm0023724', 'Giovanni Amadei', '0', '0')
# ('nm0023731', 'Celina Amadeo', '0', '0')
# ('nm0023735', 'Ricardo Amadeo', '0', '0')
# ('nm0023746', 'Nicoletta Amadio', '0', '0')
# ('nm0023747', 'Silvio Amadio', '1926', '1995')
# ('nm0023753', 'Cecília Amado', '1976', '0')
# ('nm0023759', 'François Amado', '0', '0')
# ('nm0023761', 'Gilles Amado', '0', '0')
# ('nm0023762', 'Ignacio Amado', '0', '0')
# ('nm0023763', 'James Amado', '0', '0')
# ('nm0023776', 'Alfonso Amador', '0', '0')
# ('nm0023784', 'Carolina Amador', '0', '0')
# ('nm0023793', 'Humberto Amador', '1970', '0')
# ('nm0023801', 'Miranda Amador', '0', '0')
# ('nm0023810', 'Zenaida Amador', '1933', '2008')
# ('nm0023813', 'Luis César Amadori', '1903', '1977')
# ('nm0023814', 'Ugo Amadoro', '1908', '0')
# ('nm0023818', 'Richard Amadril', '0', '0')
# ('nm0023819', 'Alessandro Amaducci', '0', '0')
# ('nm0023824', 'Gilyak Amagasaki', '0', '0')
# ('nm0023827', 'S. Amaglobeli', '0', '0')
# ('nm0023832', 'Mathieu Amalric', '1965', '0')
# ('nm0023852', 'J.K. Amalou', '0', '0')
# ('nm0023855', 'Leonid Amalrik', '1905', '1997')
# ('nm0023859', 'Keita Amemiya', '1959', '0')
# ('nm0023861', 'Yoshimitsu Amamori', '0', '0')
# ('nm0023866', 'Leigh Aman', '1913', '1990')
# ('nm0023872', 'Javier Amancio', '0', '0')
# ('nm0023874', 'Frédérique Amand', '0', '0')
# ('nm0023877', 'Paul Amand', '0', '0')
# ('nm0023883', 'Amanda White', '1982', '0')
# ('nm0023885', 'Tom Amandes', '1959', '0')
# ('nm0023901', 'Frank Amann', '1961', '0')
# ('nm0023902', 'Gerhard Ammann', '0', '0')
# ('nm0023920', 'Shin Amano', '0', '0')
# ('nm0023921', 'Tengai Amano', '0', '0')
# ('nm0023929', 'Charles Band', '1951', '0')
# ('nm0023936', 'Amar', '0', '0')
# ('nm0023939', 'Amram Amar', '0', '0')
# ('nm0023943', 'Denis Amar', '1946', '0')
# ('nm0023944', 'Gamal Ammar', '0', '0')
# ('nm0023945', 'Georges Amar', '0', '0')
# ('nm0023947', 'Henri Paul Amar', '0', '0')
# ('nm0023961', 'Zoran Amar', '1954', '0')
# ('nm0023962', 'Gogo Amara', '0', '0')
# ('nm0023967', 'Maurice Amaraggi', '0', '0')
# ('nm0023971', 'Cristiano Amaral', '0', '0')
# ('nm0023972', 'Cristina Amaral', '0', '0')
# ('nm0023973', 'Dado Amaral', '0', '0')
# ('nm0023978', 'Jeff Amaral', '0', '0')
# ('nm0023994', 'María Amaral', '0', '0')
# ('nm0023996', 'Milton Amaral', '1934', '1995')
# ('nm0023998', 'Nazareth Amaral', '0', '0')
# ('nm0024007', 'Roy Alan Amaral', '0', '0')
# ('nm0024013', 'Suzana Amaral', '1932', '2020')
# ('nm0024015', 'Tata Amaral', '1961', '0')
# ('nm0024019', 'Vera Amaral', '0', '0')
# ('nm0024026', 'Cassio Amarante', '0', '0')
# ('nm0024039', 'Amarjeet', '0', '0')
# ('nm0024061', 'K. Amarnath', '1914', '1983')
# ('nm0024063', 'Manuel Amaro da Costa', '1966', '0')
# ('nm0024093', 'Vasil Amashukeli', '0', '0')
# ('nm0024102', 'Frederic Amat', '1952', '0')
# ('nm0024104', 'Jorge Amat', '0', '0')
# ('nm0024105', 'Jose Amat', '0', '0')
# ('nm0024110', 'Gaetano Amata', '1912', '0')
# ('nm0024120', 'Rod Amateau', '1923', '2003')
# ('nm0024121', 'Todd Amateau', '0', '0')
# ('nm0024126', 'Claudio Amati', '0', '0')
# ('nm0024127', 'Edmondo Amati', '1920', '1992')
# ('nm0024138', 'Adrienne Amato', '0', '0')
# ('nm0024143', 'Barbara Amato', '0', '0')
# ('nm0024155', 'Giuseppe Amato', '1899', '1964')
# ('nm0024161', 'Kelly Amato', '0', '0')
# ('nm0024173', 'Massimiliano Amato', '1963', '0')
# ('nm0024184', 'Tommy Amato', '0', '0')
# ('nm0024186', 'Victor Amato', '0', '0')
# ('nm0024203', 'Stefano Amatucci', '0', '0')
# ('nm0024237', 'Bert Amazan Jr.', '0', '0')
# ('nm0024239', 'Jun Amazan', '0', '0')
# ('nm0024252', 'Andrea Ambandos', '0', '0')
# ('nm0024258', 'Patrice Ambard', '0', '0')
# ('nm0024265', 'Amber Production Team', '0', '0')
# ('nm0024281', 'Lucas Amberg', '0', '0')
# ('nm0024290', 'Jonathan Amberston', '0', '0')
# ('nm0024303', 'Ambili', '0', '0')
# ('nm0024304', 'V.J. Ambily', '0', '0')
# ('nm0024308', 'Gunila Ambjörnsson', '1938', '2013')
# ('nm0024313', 'Lars Amble', '1939', '2015')
# ('nm0024325', 'Ned Ambler', '1969', '0')
# ('nm0024347', 'Simon Ambridge', '0', '0')
# ('nm0024355', 'José Ambriz', '0', '0')
# ('nm0024357', 'Brenda Ambrize', '0', '0')
# ('nm0024358', 'Hal Ambro', '1913', '1990')
# ('nm0024372', 'Otto Ambros', '1910', '1979')
# ('nm0024377', 'Martin Ambrosch', '1964', '0')
# ('nm0024380', 'Anna Ambrose', '1944', '1985')
# ('nm0024388', 'David Ambrose', '1943', '0')
# ('nm0024399', 'Joe Ambrose', '0', '0')
# ('nm0024403', 'Ken Ambrose', '0', '0')
# ('nm0024406', 'Marc Ambrose', '0', '0')
# ('nm0024415', 'Roger C. Ambrose', '0', '0')
# ('nm0024419', 'Sharon Ambrose', '0', '0')
# ('nm0024441', 'Guglielmo Ambrosi', '0', '0')
# ('nm0024464', 'Arturo Ambrosio', '1870', '1960')
# ('nm0024465', 'Frederic Ambrosio', '0', '0')
# ('nm0024475', 'Scott Ambrozy', '0', '0')
# ('nm0024482', 'Maria Stilde Ambruzzi', '0', '0')
# ('nm0024490', 'Mark Ambury', '0', '0')
# ('nm0024496', 'Adam Amdur', '0', '0')
# ('nm0024498', 'Neil Amdur', '0', '0')
# ('nm0024504', 'Steven Ameche', '0', '0')
# ('nm0024510', 'Bruce Amedick', '0', '0')
# ('nm0024513', 'Tomas Amedé', '0', '0')
# ('nm0024521', 'Jorge Ameer', '1972', '0')
# ('nm0024527', 'Boel Amegrissi', '0', '0')
# ('nm0024538', 'Paolo Ameli', '0', '0')
# ('nm0024551', 'José María de Amelivia', '0', '0')
# ('nm0024554', 'Deborah Amelon', '1955', '0')
# ('nm0024563', 'Carole Amen', '0', '0')
# ('nm0024573', 'Richard Amend', '0', '0')
# ('nm0024575', 'Scott Nicholas Amendolare', '0', '0')
# ('nm0024578', 'Antonio Amendola', '0', '0')
# ('nm0024580', 'Claudio Amendola', '1963', '0')
# ('nm0024589', 'Mario Amendola', '1910', '1993')
# ('nm0024596', 'Don Amendolia', '1945', '0')
# ('nm0024597', 'Luis Amendolla', '0', '0')
# ('nm0024606', 'Don Ament', '1905', '1988')
# ('nm0024614', 'William C. Ament', '0', '0')
# ('nm0024615', 'Alessandra Amenta', '0', '0')
# ('nm0024617', 'Marco Amenta', '1970', '0')
# ('nm0024619', 'Pino Amenta', '1952', '0')
# ('nm0024620', 'Vittorio Armentano', '0', '0')
# ('nm0024622', 'Alejandro Amenábar', '1972', '0')
# ('nm0024647', 'Cindy Ferda', '0', '0')
# ('nm0024658', 'John Amero', '1939', '0')
# ('nm0024659', 'Lem Amero', '1937', '1989')
# ('nm0024662', 'Bill Amerson', '1938', '2015')
# ('nm0024672', 'Allyson Ames', '1937', '1999')
# ('nm0024694', 'E. Preston Ames', '1906', '1983')
# ('nm0024706', 'Gerald Ames', '1881', '1933')
# ('nm0024726', 'Kent Ames', '0', '0')
# ('nm0024735', 'Paul Ames', '0', '0')
# ('nm0024741', 'Ron Ames', '0', '0')
# ('nm0024746', 'Stefani Ames', '0', '0')
# ('nm0024767', 'Edward Amet', '1860', '1948')
# ('nm0024782', 'Carlos Amezcua', '1953', '0')
# ('nm0024784', 'Steve Amezdroz', '0', '0')
# ('nm0024786', 'José Amezquita', '0', '0')
# ('nm0024790', 'Javier G. Amezúa', '0', '0')
# ('nm0024801', 'Najib Amhali', '1971', '0')
# ('nm0024807', 'Ami Tomobuki', '0', '0')
# ('nm0024808', 'Franck Amiack', '0', '0')
# ('nm0024815', 'Josep Amich i Bert', '1888', '1965')
# ('nm0024825', 'Vanio Amici', '0', '0')
# ('nm0024832', 'Tom Amick', '0', '0')
# ('nm0024836', 'Gianni Amico', '1933', '1990')
# ('nm0024839', 'Robert Amico', '1953', '0')
# ('nm0024844', 'Roberto Amicucci', '0', '0')
# ('nm0024847', 'Sergio Amidei', '1904', '1981')
# ('nm0024850', 'Souad Amidou', '1959', '0')
# ('nm0024867', 'Caroline Amies', '1951', '0')
# ('nm0024869', 'Toby Amies', '0', '0')
# ('nm0024874', 'Cesar Amigo', '1924', '1987')
# ('nm0024882', 'Rogelio Amigo', '0', '0')
# ('nm0024887', 'Santiago Amigorena', '1962', '0')
# ('nm0024888', 'Jean-François Amiguet', '1950', '0')
# ('nm0024889', 'Philippe Amiguet', '0', '0')
# ('nm0024896', 'Grace Amilbangsa', '0', '0')
# ('nm0024908', 'M. Amin', '1924', '2003')
# ('nm0024909', 'Mark Amin', '0', '0')
# ('nm0024912', 'Shimit Amin', '0', '0')
# ('nm0024916', 'Yôko Aminaka', '0', '0')
# ('nm0024925', 'Hossein Amini', '1966', '0')
# ('nm0024927', 'Rene Amini', '0', '0')
# ('nm0024930', 'Tetsurô Amino', '1955', '0')
# ('nm0024933', 'Elena Aminova', '1949', '0')
# ('nm0024942', 'Imri Nasution', '0', '0')
# ('nm0024949', 'Guidi Amir', '0', '0')
# ('nm0024965', 'Helena Amiradzibi-Stawinska', '1932', '2017')
# ('nm0024984', 'Viacheslav Amirhanian', '0', '0')
# ('nm0024993', 'Jon Amirkhan', '0', '0')
# ('nm0024999', 'Ardak Amirkulov', '1955', '0')
# ('nm0025008', 'Stephen Amis', '1966', '0')
# ('nm0025015', 'Jonathan Amitay', '0', '0')
# ('nm0025016', 'Shirel Amitay', '0', '0')
# ('nm0025017', 'Yaron Amitay', '0', '0')
# ('nm0025021', 'Francesca Amitrano', '0', '0')
# ('nm0025026', 'Susan Amkraut', '0', '0')
# ('nm0025027', 'Aslam Amlani', '1971', '0')
# ('nm0025028', 'Claus-Rudolf Amler', '1968', '0')
# ('nm0025029', 'Michaela Amler', '0', '0')
# ('nm0025030', 'Patricia Amlin', '0', '0')
# ('nm0025045', 'Lukas Ammann', '1912', '2017')
# ('nm0025047', 'Max Peter Ammann', '1929', '0')
# ('nm0025048', 'Michael Ammann', '1957', '0')
# ('nm0025052', 'Niccolò Ammaniti', '1966', '0')
# ('nm0025062', 'Harry Ammerlaan', '0', '0')
# ('nm0025070', 'Sergio Ammirata', '1935', '0')
# ('nm0025083', 'Jack Ammon', '0', '0')
# ('nm0025094', 'John Ammonds', '1924', '2013')
# ('nm0025104', 'Kjeld Ammundsen', '1939', '0')
# ('nm0025107', 'Antonio del Amo', '1911', '1991')
# ('nm0025112', 'Michael Amo', '0', '0')
# ('nm0025117', 'Álvaro del Amo', '0', '0')
# ('nm0025119', 'Kwame Amoaku', '0', '0')
# ('nm0025133', 'Diego Amodio', '0', '0')
# ('nm0025138', 'Anthony Amoia', '1971', '0')
# ('nm0025146', 'Hansjörg Amon', '0', '0')
# ('nm0025157', 'Sergio Amon', '1960', '0')
# ('nm0025159', 'Kimberly Amona', '0', '0')
# ('nm0025162', 'Tony Amoni', '0', '0')
# ('nm0025172', 'Ilia Amoorsky', '0', '0')
# ('nm0025181', 'Jay Amor', '1958', '0')
# ('nm0025184', 'Lucy Amor', '0', '0')
# ('nm0025187', 'M. Antunes Amor', '0', '0')
# ('nm0025189', 'Maximiliano Amor', '0', '0')
# ('nm0025203', 'Alexis Amore', '1978', '0')
# ('nm0025209', 'Kym Wilde', '1969', '0')
# ('nm0025230', 'Joana Amorim', '0', '0')
# ('nm0025241', 'Vicente Amorim', '1966', '0')
# ('nm0025251', 'Carmine Amoroso', '1963', '0')
# ('nm0025263', 'Marino Amoruso', '1955', '0')
# ('nm0025271', 'Jordi Amorós', '0', '0')
# ('nm0025296', 'Dick Amos', '0', '0')
# ('nm0025299', 'Duane Amos', '0', '0')
# ('nm0025304', 'Gerlind Amos', '0', '0')
# ('nm0025305', 'Hank Amos', '0', '0')
# ('nm0025311', 'K.C. Amos', '0', '0')
# ('nm0025316', 'Matthew Amos', '0', '0')
# ('nm0025336', 'Yves Amoureux', '0', '0')
# ('nm0025337', 'Claire Amoureux', '0', '0')
# ('nm0025340', 'Sylvestre Amoussou', '0', '0')
# ('nm0025341', 'Simone Amouyal', '0', '0')
# ('nm0025344', 'Paul Amoyel', '0', '0')
# ('nm0025345', 'José Amozurrutia', '0', '0')
# ('nm0025346', 'Kokayi Ampah', '0', '0')
# ('nm0025347', 'King Ampaw', '0', '0')
# ('nm0025349', 'Eleni Ampelakiotou', '1959', '0')
# ('nm0025355', 'John Amplas', '1949', '0')
# ('nm0025374', 'Robert Amram', '1938', '0')
# ('nm0025375', 'Emanuel Amrami', '0', '0')
# ('nm0025388', 'Sharon Amrani', '1970', '2001')
# ('nm0025399', 'Kamal Amrohi', '1918', '1993')
# ('nm0025418', 'Daniel F. Amselem', '0', '0')
# ('nm0025435', 'Simon Amstell', '1979', '0')
# ('nm0025451', 'Michael Amter', '0', '0')
# ('nm0025456', 'Allan Amtzis', '0', '0')
# ('nm0025457', 'Kepa Amuchastegui', '0', '0')
# ('nm0025474', 'Tore Amundsen', '1927', '0')
# ('nm0025475', 'Michael Amundson', '0', '0')
# ('nm0025486', 'Ilya Amursky', '1963', '0')
# ('nm0025494', 'Christopher Amy', '0', '0')
# ('nm0025504', 'Julian Amyes', '1917', '1992')
# ('nm0025509', 'Marc Amyot', '0', '0')
# ('nm0025517', 'Pierre Amzallag', '1963', '1999')
# ('nm0025533', 'Federico Amérigo', '0', '0')
# ('nm0025534', 'Jean-Pierre Améris', '1961', '0')
# ('nm0025538', 'Patxi Amezcua', '0', '0')
# ('nm0025541', 'Bin An', '0', '0')
# ('nm0025543', 'Dick An', '0', '0')
# ('nm0025546', 'Hark-On Fung', '1948', '2016')
# ('nm0025562', 'Thom Anable', '0', '0')
# ('nm0025573', 'Orhan Anafarta', '1972', '0')
# ('nm0025576', 'Dhimiter Anagnosti', '1936', '0')
# ('nm0025579', 'Errikos Anagnostopoulos', '0', '0')
# ('nm0025586', 'Anais', '1972', '0')
# ('nm0025602', 'Kenji Anan', '1962', '0')
# ('nm0025603', 'Anand', '0', '0')
# ('nm0025608', 'Chetan Anand', '1921', '1997')
# ('nm0025609', 'Deepak Anand', '0', '0')
# ('nm0025611', 'Gogi Anand', '0', '0')
# ('nm0025613', 'Inder Raj Anand', '0', '1987')
# ('nm0025617', 'Ketan Anand', '0', '0')
# ('nm0025626', 'Suneil Anand', '1956', '0')
# ('nm0025627', 'Tinnu Anand', '1953', '0')
# ('nm0025629', 'Vijay Anand', '1934', '2004')
# ('nm0025632', 'Vivek Anand', '0', '0')
# ('nm0025640', 'Jay Anania', '0', '0')
# ('nm0025643', 'Maurizio Anania', '0', '0')
# ('nm0025655', 'S.K. Ananthachari', '0', '0')
# ('nm0025681', 'Glen Anastaiou', '0', '0')
# ('nm0025696', 'Stefan Anastasiu', '0', '0')
# ('nm0025697', 'Giorgos Anastasiadis', '0', '0')
# ('nm0025706', 'Javier Anastasio', '0', '0')
# ('nm0025712', 'Glen Anastasiou', '0', '0')
# ('nm0025732', 'Anatoliy Artamonov', '0', '0')
# ('nm0025745', 'Elena Anaya', '1975', '0')
# ('nm0025763', 'Tânia Anaya', '0', '0')
# ('nm0025773', 'Shûichi Anbara', '0', '0')
# ('nm0025778', 'Jerzy Antczak', '1929', '0')
# ('nm0025784', 'Jordan Ancel', '0', '0')
# ('nm0025800', 'Carlo Ancelotti', '1959', '0')
# ('nm0025801', 'Gaston Ancelovici', '1945', '2017')
# ('nm0025805', 'Rajiv Anchal', '0', '0')
# ('nm0025813', 'José de Anchieta', '1948', '2019')
# ('nm0025820', 'Andrei Anchugov', '0', '0')
# ('nm0025825', 'Marcello Daciano', '1977', '0')
# ('nm0025832', 'Alberto Ancilotto', '1903', '1971')
# ('nm0025836', 'Verónica Anciones', '0', '0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-bceaa24b2056> in <module>
#      15         print(data)
#      16         curs.execute(sql,data)
# ---> 17         conn.commit()
#      18
#      19 f.close()
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pymysql\connections.py in commit(self)
#     468         """
#     469         self._execute_command(COMMAND.COM_QUERY, "COMMIT")
# --> 470         self._read_ok_packet()
#     471
#     472     def rollback(self):
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pymysql\connections.py in _read_ok_packet(self)
#     441
#     442     def _read_ok_packet(self):
# --> 443         pkt = self._read_packet()
#     444         if not pkt.is_ok_packet():
#     445             raise err.OperationalError(2014, "Command Out of Sync")
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     690         buff = bytearray()
#     691         while True:
# --> 692             packet_header = self._read_bytes(4)
#     693             # if DEBUG: dump_packet(packet_header)
#     694
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pymysql\connections.py in _read_bytes(self, num_bytes)
#     730         while True:
#     731             try:
# --> 732                 data = self._rfile.read(num_bytes)
#     733                 break
#     734             except (IOError, OSError) as e:
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
f = open('name.basics.tsv', 'r', encoding='utf=8')
rd = csv.reader(f, delimiter='\t')

conn=pymysql.connect(host='localhost',user='gotaek',password='gotaek',db='IMDB')
curs=conn.cursor(pymysql.cursors.DictCursor)

sql="insert ignore into writer (writerId,primaryName,birthYear,deathYear) values(%s,%s,%s,%s)"
next(rd)
for line in rd:
    
    if "writer" in line[4] :
        a=line[2] if line[2]!="\\N" else '0'
        b=line[3] if line[3] !="\\N" else '0'
        data=(line[0],line[1],a,b )
    
        print(data)
        curs.execute(sql,data)
        conn.commit()

f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-05288a1195f9> in <module>
#       1 f = open('name.basics.tsv', 'r', encoding='utf=8')
# ----> 2 rd = csv.reader(f, delimiter='\t')
#       3
#       4 conn=pymysql.connect(host='localhost',user='gotaek',password='gotaek',db='IMDB')
#       5 curs=conn.cursor(pymysql.cursors.DictCursor)
#
# NameError: name 'csv' is not defined
