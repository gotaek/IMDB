# %%
import csv
import pymysql

# %%
f = open('title.basics.tsv', 'r', encoding='utf=8')
rd = csv.reader(f, delimiter='\t')

conn=pymysql.connect(host='localhost',user='gotaek',password='gotaek',db='IMDB')
curs=conn.cursor(pymysql.cursors.DictCursor)

sql="insert ignore into works (workId,titleType,primaryTitle,originalTitle,isAdult,startYear,endYear,runtimeMinutes) values(%s,%s,%s,%s,%s,%s,%s,%s)"

next(rd)

for line in rd:
    isAdult=line[4]
    startYear=line[5]
    endYear=line[6]
    runtimeMinutes=line[7]
    for i in range(4,8):
        if line[4]!="0":
            isAdult=1
        if line[5]=="\\N":
            startYear=0
        if line[6]=="\\N":
            endYear=0
        if line[7]=="\\N":
            runtimeMinutes=0
    data=(line[0],line[1],line[2],line[3],isAdult,startYear,endYear,runtimeMinutes)
    print(data)
    
    curs.execute(sql,data)
    conn.commit()
f.close()
# Out:
# 0, '5')
# ('tt0000356', 'short', 'Frivolité', 'Frivolité', '0', '1901', 0, 0)
# ('tt0000357', 'short', 'The Haunted Curiosity Shop', 'The Haunted Curiosity Shop', '0', '1901', 0, '2')
# ('tt0000358', 'short', 'History of a Crime', "Histoire d'un crime", '0', '1901', 0, '5')
# ('tt0000359', 'short', 'The India Rubber Head', "L'homme à la tête en caoutchouc", '0', '1901', 0, '3')
# ('tt0000360', 'short', 'Hussards et grisettes', 'Hussards et grisettes', '0', '1901', 0, 0)
# ('tt0000361', 'short', 'Lavatory moderne', 'Lavatory moderne', '0', '1901', 0, 0)
# ('tt0000362', 'short', 'Lecture quotidienne', 'Lecture quotidienne', '0', '1901', 0, 0)
# ('tt0000363', 'short', 'Magical Sword', 'The Magic Sword', '0', '1901', 0, '2')
# ('tt0000364', 'short', 'Panorama of Esplanade by Night', 'Panorama of Esplanade by Night', '0', '1901', 0, '1')
# ('tt0000365', 'short', 'Parada de Bombeiros', 'Parada de Bombeiros', '0', '1901', 0, 0)
# ('tt0000366', 'short', 'Uma Parada dos Alunos da Casa Pia de Lisboa', 'Uma Parada dos Alunos da Casa Pia de Lisboa', '0', '1901', 0, 0)
# ('tt0000367', 'short', 'Pas de colombine', 'Pas de colombine', '0', '1901', 0, 0)
# ('tt0000368', 'short', 'Little Red Riding Hood', 'Le petit chaperon rouge', '0', '1901', 0, 0)
# ('tt0000369', 'short', "A Road for Children's Bicycles in Barcelona", 'Pista de bicicletas para niños en Barcelona', '0', '1901', 0, '3')
# ('tt0000370', 'short', "Scrooge; or Marley's Ghost", "Scrooge; or Marley's Ghost", '0', '1901', 0, '6')
# ('tt0000371', 'short', "Scène d'amour", "Scène d'amour", '0', '1901', 0, 0)
# ('tt0000372', 'short', "Scène d'ivresse", "Scène d'ivresse", '0', '1901', 0, 0)
# ('tt0000373', 'short', "The Devil's Seven Castles", 'Les sept châteaux du diable', '0', '1902', 0, '11')
# ('tt0000374', 'short', 'Tel est pris qui croyait prendre', 'Tel est pris qui croyait prendre', '0', '1901', 0, 0)
# ('tt0000375', 'short', 'Uma Tourada à Antiga Portuguesa', 'Uma Tourada à Antiga Portuguesa', '0', '1901', 0, 0)
# ('tt0000376', 'short', 'A táncz', 'A táncz', '0', '1901', 0, 0)
# ('tt0000377', 'short', 'Undressing Extraordinary', 'Undressing Extraordinary', '0', '1901', 0, '3')
# ('tt0000378', 'short', 'Les vagues', 'Les vagues', '0', '1901', 0, 0)
# ('tt0000379', 'short', 'Visita de la escuadra inglesa a Barcelona', 'Visita de la escuadra inglesa a Barcelona', '0', '1901', 0, '6')
# ('tt0000380', 'short', 'Sleeping Beauty', 'La belle au bois dormant', '0', '1903', 0, 0)
# ('tt0000381', 'short', "Buffalo Bill's Wild West Show", "Buffalo Bill's Wild West Show", '0', '1902', 0, 0)
# ('tt0000382', 'short', 'Carnaval en las ramblas', 'Carnaval en las ramblas', '0', '1902', 0, '9')
# ('tt0000383', 'short', 'Carreras de caballos en el hipódromo de Barcelona', 'Carreras de caballos en el hipódromo de Barcelona', '0', '1902', 0, '6')
# ('tt0000384', 'short', 'Les chiens savants', 'Les chiens savants', '0', '1902', 0, '3')
# ('tt0000385', 'short', 'Les clowns', 'Les clowns', '0', '1902', 0, 0)
# ('tt0000386', 'short', 'La cour des miracles', 'La cour des miracles', '0', '1902', 0, 0)
# ('tt0000387', 'short', 'The Coronation of King Edward VII', 'The Coronation of Edward VII', '0', '1902', 0, '4')
# ('tt0000388', 'short', 'Danse excentrique', 'Danse excentrique', '0', '1902', 0, '2')
# ('tt0000389', 'short', 'Danse fantaisiste', 'Danse fantaisiste', '0', '1902', 0, 0)
# ('tt0000390', 'short', 'Danse mauresque', 'Danse mauresque', '0', '1902', 0, 0)
# ('tt0000391', 'short', 'La dent récalcitrante', 'La dent récalcitrante', '0', '1902', 0, 0)
# ('tt0000392', 'short', 'The Enchanted Cup', 'The Enchanted Cup', '0', '1903', 0, 0)
# ('tt0000393', 'short', 'En faction', 'En faction', '0', '1902', 0, 0)
# ('tt0000394', 'short', 'Farces de cuisinière', 'Farces de cuisinière', '0', '1902', 0, 0)
# ('tt0000395', 'short', 'La fiole enchantée', 'La fiole enchantée', '0', '1902', 0, 0)
# ('tt0000396', 'short', 'Fruits de saison', 'Fruits de saison', '0', '1902', 0, 0)
# ('tt0000397', 'short', 'La gavotte', 'La gavotte', '0', '1902', 0, 0)
# ('tt0000398', 'short', 'La gigue', 'La gigue', '0', '1902', 0, 0)
# ('tt0000399', 'short', 'Jack and the Beanstalk', 'Jack and the Beanstalk', '0', '1902', 0, '10')
# ('tt0000400', 'short', 'Le lion savant', 'Le lion savant', '0', '1902', 0, 0)
# ('tt0000401', 'short', 'Le marchand de ballons', 'Le marchand de ballons', '0', '1902', 0, 0)
# ('tt0000402', 'short', 'Mother Goose Nursery Rhymes', 'Mother Goose Nursery Rhymes', '0', '1902', 0, 0)
# ('tt0000403', 'short', 'Le pommier', 'Le pommier', '0', '1902', 0, 0)
# ('tt0000404', 'short', 'Pour secouer la salade', 'Pour secouer la salade', '0', '1902', 0, 0)
# ('tt0000405', 'short', 'La première gamelle', 'La première gamelle', '0', '1902', 0, 0)
# ('tt0000406', 'short', 'The Prince of Darkness', 'The Prince of Darkness', '0', '1900', 0, 0)
# ('tt0000407', 'short', 'Procesión de las hijas de María de la parroquia de Sans', 'Procesión de las hijas de María de la parroquia de Sans', '0', '1902', 0, 0)
# ('tt0000408', 'short', 'Quadrille réaliste', 'Quadrille réaliste', '0', '1902', 0, 0)
# ('tt0000409', 'short', 'Midwife to the Upper Classes', 'Sage-femme de première classe', '0', '1902', 0, '4')
# ('tt0000410', 'short', 'Demolishing and Building Up the Star Theatre', 'Demolishing and Building Up the Star Theatre', '0', '1901', 0, '2')
# ('tt0000411', 'short', 'Trompé mais content', 'Trompé mais content', '0', '1902', 0, 0)
# ('tt0000412', 'short', 'The Troublesome Fly', 'The Troublesome Fly', '0', '1900', 0, 0)
# ('tt0000413', 'short', "The Devil's Money Bags", 'Les trésors de satan', '0', '1902', 0, '3')
# ('tt0000414', 'short', 'Uncle Josh at the Moving Picture Show', 'Uncle Josh at the Moving Picture Show', '0', '1902', 0, '2')
# ('tt0000415', 'short', 'A Peculiar Cabinet', 'Une scène en cabinet particulier vue à travers le trou de la serrure', '0', '1902', 0, 0)
# ('tt0000416', 'short', 'Alcohol and Its Victims', "Les victimes de l'alcoolisme", '0', '1902', 0, '4')
# ('tt0000417', 'short', 'A Trip to the Moon', 'Le voyage dans la lune', '0', '1902', 0, '13')
# ('tt0000418', 'short', 'The Wild Man of Borneo', 'The Wild Man of Borneo', '0', '1902', 0, 0)
# ('tt0000419', 'short', "L'équilibriste", "L'équilibriste", '0', '1902', 0, 0)
# ('tt0000420', 'short', 'Alice in Wonderland', 'Alice in Wonderland', '0', '1903', 0, '8')
# ('tt0000421', 'short', 'Les apaches pas veinards', 'Les apaches pas veinards', '0', '1903', 0, 0)
# ('tt0000422', 'short', "Les aventures d'un voyageur trop pressé", "Les aventures d'un voyageur trop pressé", '0', '1903', 0, 0)
# ('tt0000423', 'short', 'The Enchanted Box', 'La boîte à malice', '0', '1903', 0, '1')
# ('tt0000424', 'short', 'Les braconniers', 'Les braconniers', '0', '1903', 0, 0)
# ('tt0000425', 'short', "Buffalo Bill's Parade", "Buffalo Bill's Parade", '0', '1903', 0, 0)
# ('tt0000426', 'short', "Buffalo Bill's Street Parade", "Buffalo Bill's Street Parade", '0', '1903', 0, 0)
# ('tt0000427', 'short', 'Cake-walk de la pendule', 'Cake-walk de la pendule', '0', '1903', 0, 0)
# ('tt0000428', 'short', 'Carreras de bicicletas en el parque', 'Carreras de bicicletas en el parque', '0', '1903', 0, 0)
# ('tt0000429', 'short', 'La chasse au cambrioleur', 'La chasse au cambrioleur', '0', '1903', 0, 0)
# ('tt0000430', 'short', 'A Chess Dispute', 'A Chess Dispute', '0', '1903', 0, '1')
# ('tt0000431', 'short', 'Comme on fait son lit on se couche', 'Comme on fait son lit on se couche', '0', '1903', 0, 0)
# ('tt0000432', 'short', 'How Monsieur Takes His Bath', 'Comment monsieur prend son bain', '0', '1903', 0, '1')
# ('tt0000433', 'short', 'Compagnons de voyage encombrants', 'Compagnons de voyage encombrants', '0', '1903', 0, 0)
# ('tt0000434', 'short', "Dorothy's Dream", "Dorothy's Dream", '0', '1903', 0, 0)
# ('tt0000435', 'short', 'Enlèvement en automobile et mariage précipité', 'Enlèvement en automobile et mariage précipité', '0', '1903', 0, 0)
# ('tt0000436', 'short', 'An Extraordinary Cab Accident', 'An Extraordinary Cab Accident', '0', '1903', 0, '1')
# ('tt0000437', 'short', 'Faust et Méphistophélès', 'Faust et Méphistophélès', '0', '1903', 0, '2')
# ('tt0000438', 'short', 'Le fiancé ensorcelé', 'Le fiancé ensorcelé', '0', '1903', 0, 0)
# ('tt0000439', 'short', 'The Great Train Robbery', 'The Great Train Robbery', '0', '1903', 0, '11')
# ('tt0000440', 'short', 'La guirlande merveilleuse', 'La guirlande merveilleuse', '0', '1903', 0, '4')
# ('tt0000441', 'short', 'Gulliver en el país de los gigantes', 'Gulliver en el país de los gigantes', '0', '1903', 0, 0)
# ('tt0000442', 'short', 'Capital Execution', 'Henrettelsen', '0', '1903', 0, 0)
# ('tt0000443', 'short', 'Hiawatha', 'Hiawatha, the Messiah of the Ojibway', '0', '1903', 0, '15')
# ('tt0000444', 'short', 'Illusionniste renversant', 'Illusionniste renversant', '0', '1903', 0, 0)
# ('tt0000445', 'short', 'Jocko musicien', 'Jocko musicien', '0', '1903', 0, 0)
# ('tt0000446', 'short', 'Kit Carson', 'Kit Carson', '0', '1903', 0, '21')
# ('tt0000447', 'short', 'Life of an American Fireman', 'Life of an American Fireman', '0', '1903', 0, '6')
# ('tt0000448', 'short', 'Le liqueur du couvent', 'Le liqueur du couvent', '0', '1903', 0, 0)
# ('tt0000449', 'short', 'Lutteurs américains', 'Lutteurs américains', '0', '1903', 0, 0)
# ('tt0000450', 'short', 'La main du professeur Hamilton ou le roi des dollars', 'La main du professeur Hamilton ou le roi des dollars', '0', '1903', 0, 0)
# ('tt0000451', 'short', "Mary Jane's Mishap", "Mary Jane's Mishap", '0', '1903', 0, '4')
# ('tt0000452', 'short', "The Messenger Boy's Mistake", "The Messenger Boy's Mistake", '0', '1903', 0, '2')
# ('tt0000453', 'short', 'Modelage express', 'Modelage express', '0', '1903', 0, 0)
# ('tt0000454', 'short', 'La mouche', 'La mouche', '0', '1903', 0, 0)
# ('tt0000455', 'short', 'The Music Lover', 'Le mélomane', '0', '1903', 0, '3')
# ('tt0000456', 'short', 'N.Y. Fire Department Returning', 'N.Y. Fire Department Returning', '0', '1903', 0, 0)
# ('tt0000457', 'short', 'Ne bougeons plus', 'Ne bougeons plus', '0', '1903', 0, 0)
# ('tt0000458', 'short', 'Nos bons étudiants', 'Nos bons étudiants', '0', '1903', 0, 0)
# ('tt0000459', 'short', "Panorama of Riker's Island, N.Y.", "Panorama of Riker's Island, N.Y.", '0', '1903', 0, '2')
# ('tt0000460', 'short', 'The Pioneers', 'The Pioneers', '0', '1903', 0, '15')
# ('tt0000461', 'short', 'Potage indigeste', 'Potage indigeste', '0', '1903', 0, 0)
# ('tt0000462', 'short', 'La poule fantaisiste', 'La poule fantaisiste', '0', '1903', 0, 0)
# ('tt0000463', 'short', 'Puerto de Barcelona', 'Puerto de Barcelona', '0', '1903', 0, '1')
# ('tt0000464', 'short', 'Rip Van Winkle', 'Rip Van Winkle', '0', '1903', 0, '4')
# ('tt0000465', 'short', 'Fairyland; or, the Kingdom of the Fairies', 'Le royaume des fées', '0', '1903', 0, '16')
# ('tt0000466', 'short', 'Répétition dans un cirque', 'Répétition dans un cirque', '0', '1903', 0, 0)
# ('tt0000467', 'short', 'Secours aux naufragés', 'Secours aux naufragés', '0', '1903', 0, 0)
# ('tt0000468', 'short', 'Service précipité', 'Service précipité', '0', '1903', 0, 0)
# ('tt0000469', 'short', 'The Sick Kitten', 'The Sick Kitten', '0', '1903', 0, '1')
# ('tt0000470', 'short', "Les surprises de l'affichage", "Les surprises de l'affichage", '0', '1903', 0, 0)
# ('tt0000471', 'short', "Uncle Tom's Cabin", "Uncle Tom's Cabin", '0', '1903', 0, '13')
# ('tt0000472', 'short', "Uncle Tom's Cabin", "Uncle Tom's Cabin", '0', '1903', 0, 0)
# ('tt0000473', 'short', 'La valise enchantée', 'La valise enchantée', '0', '1905', 0, 0)
# ('tt0000474', 'short', 'Le voleur sacrilège', 'Le voleur sacrilège', '0', '1903', 0, 0)
# ('tt0000475', 'short', "Voyage of the 'Arctic'", "The Adventurous Voyage of 'The Arctic'", '0', '1903', 0, '10')
# ('tt0000476', 'short', 'Après la fête', 'Après la fête', '0', '1904', 0, 0)
# ('tt0000477', 'short', "L'assassinat du courrier de Lyon", "L'assassinat du courrier de Lyon", '0', '1904', 0, 0)
# ('tt0000478', 'short', 'Behind the Scenes', 'Behind the Scenes', '0', '1904', 0, 0)
# ('tt0000479', 'short', 'Rum vs. Cherries', 'Buy Your Own Cherries', '0', '1904', 0, '4')
# ('tt0000480', 'short', 'Le coffre enchanté', 'Le coffre enchanté', '0', '1904', 0, '3')
# ('tt0000481', 'short', "A Collier's Life", "A Collier's Life", '0', '1904', 0, 0)
# ('tt0000482', 'short', 'Comment on disperse les foules', 'Comment on disperse les foules', '0', '1904', 0, 0)
# ('tt0000483', 'short', 'Les deux rivaux', 'Les deux rivaux', '0', '1904', 0, 0)
# ('tt0000484', 'short', 'Les enfants du miracle', 'Les enfants du miracle', '0', '1904', 0, 0)
# ('tt0000485', 'short', 'La gavotte de la reine', 'La gavotte de la reine', '0', '1904', 0, 0)
# ('tt0000486', 'short', 'A Gentleman of France', 'A Gentleman of France', '0', '1905', 0, '5')
# ('tt0000487', 'short', 'The Great Train Robbery', 'The Great Train Robbery', '0', '1904', 0, '12')
# ('tt0000488', 'short', 'The Land Beyond the Sunset', 'The Land Beyond the Sunset', '0', '1912', 0, '14')
# ('tt0000489', 'short', 'La leçon de pipeau', 'La leçon de pipeau', '0', '1904', 0, 0)
# ('tt0000490', 'short', "L'oiseau envolé", "L'oiseau envolé", '0', '1904', 0, 0)
# ('tt0000491', 'short', 'Opening the Williamsburg Bridge', 'Opening the Williamsburg Bridge', '0', '1904', 0, '1')
# ('tt0000492', 'short', 'Personal', 'Personal', '0', '1904', 0, '6')
# ('tt0000493', 'short', 'Pierrot, Murderer', 'Pierrot assassin', '0', '1904', 0, 0)
# ('tt0000494', 'short', 'Le pompon malencontreux', 'Le pompon malencontreux', '0', '1904', 0, 0)
# ('tt0000495', 'short', 'The Pearl Fisher', 'Le pêcheur de perles', '0', '1907', 0, '12')
# ('tt0000496', 'short', 'Railroad Smashup', 'Railroad Smashup', '0', '1904', 0, 0)
# ('tt0000497', 'short', 'A Railway Tragedy', 'A Railway Tragedy', '0', '1904', 0, '5')
# ('tt0000498', 'short', 'Rescued by Rover', 'Rescued by Rover', '0', '1905', 0, '7')
# ('tt0000499', 'short', 'The Impossible Voyage', "Le voyage à travers l'impossible", '0', '1904', 0, '24')
# ('tt0000500', 'short', 'The Abductors', 'The Abductors', '0', '1905', 0, 0)
# ('tt0000501', 'short', 'Adventures of Sherlock Holmes', 'Adventures of Sherlock Holmes', '0', '1905', 0, 0)
# ('tt0000502', 'movie', 'Bohemios', 'Bohemios', '0', '1905', 0, '100')
# ('tt0000503', 'short', 'Corrida de beneficencia en Zaragoza, por Quinito y Montes', 'Corrida de beneficencia en Zaragoza, por Quinito y Montes', '0', '1905', 0, '2')
# ('tt0000504', 'short', 'Coso y Paseo de Santa Engracia (Calles y plazas de Zaragoza)', 'Coso y Paseo de Santa Engracia (Calles y plazas de Zaragoza)', '0', '1905', 0, 0)
# ('tt0000505', 'short', 'The Wig Chase', 'La course à la perruque', '0', '1906', 0, 0)
# ('tt0000506', 'short', 'The Effects of Too Much Scotch', "D.T.'s, or the Effect of Drink", '0', '1905', 0, 0)
# ('tt0000507', 'short', 'Departure of Peary and the Roosevelt from New York', 'Departure of Peary and the Roosevelt from New York', '0', '1905', 0, '4')
# ('tt0000508', 'short', 'Desde el coso a la calle Cerdán (Calles y plazas de Zaragoza)', 'Desde el coso a la calle Cerdán (Calles y plazas de Zaragoza)', '0', '1905', 0, 0)
# ('tt0000509', 'short', 'The Inexperienced Chauffeur', "Les débuts d'un chauffeur", '0', '1906', 0, 0)
# ('tt0000510', 'short', 'El dúo de la Africana', 'El dúo de la Africana', '0', '1905', 0, 0)
# ('tt0000511', 'short', 'Esmeralda', 'Esmeralda', '0', '1905', 0, '10')
# ('tt0000512', 'short', 'Funeral of Hiram Cronk', 'Funeral of Hiram Cronk', '0', '1905', 0, '4')
# ('tt0000513', 'short', 'Gigantes y cabezudos', 'Gigantes y cabezudos', '0', '1905', 0, 0)
# ('tt0000514', 'short', 'Los guapos de la Vaquería del Parque', 'Los guapos de la Vaquería del Parque', '0', '1905', 0, 0)
# ('tt0000515', 'short', 'Los guapos del parque', 'Los guapos del parque', '0', '1904', 0, '6')
# ('tt0000516', 'short', 'The Electric Hotel', 'El hotel eléctrico', '0', '1908', 0, '8')
# ('tt0000517', 'short', 'El húsar de la guardia', 'El húsar de la guardia', '0', '1905', 0, 0)
# ('tt0000518', 'short', 'Juanito el forzudo', 'Juanito el forzudo', '0', '1905', 0, 0)
# ('tt0000519', 'short', 'The Kleptomaniac', 'The Kleptomaniac', '0', '1905', 0, '8')
# ('tt0000520', 'short', 'The Life of Charles Peace', 'The Life of Charles Peace', '0', '1905', 0, '14')
# ('tt0000521', 'short', 'The Little Train Robbery', 'The Little Train Robbery', '0', '1905', 0, '12')
# ('tt0000522', 'short', 'The Moonshiners', 'The Moonshiners', '0', '1905', 0, 0)
# ('tt0000523', 'short', 'Moose Hunting in Newfoundland', 'Moose Hunting in Newfoundland', '0', '1905', 0, 0)
# ('tt0000524', 'short', 'New York Subway', 'New York Subway', '0', '1905', 0, '6')
# ('tt0000525', 'short', 'Hanging at Jefferson City', 'Pendaison à Jefferson City', '0', '1910', 0, '7')
# ('tt0000526', 'short', 'Pennsylvania Tunnel Excavation', 'Pennsylvania Tunnel Excavation', '0', '1905', 0, 0)
# ('tt0000527', 'short', 'Plaza de la Magdalena (Calles y plazas de Zaragoza)', 'Plaza de la Magdalena (Calles y plazas de Zaragoza)', '0', '1905', 0, 0)
# ('tt0000528', 'short', 'Raffles, the Amateur Cracksman', 'Raffles, the Amateur Cracksman', '0', '1905', 0, '15')
# ('tt0000529', 'short', 'Reuben in the Opium Joint', 'Reuben in the Opium Joint', '0', '1905', 0, 0)
# ('tt0000530', 'short', 'Se da de comer', 'Se da de comer', '0', '1905', 0, 0)
# ('tt0000531', 'short', 'Los sitios de Chile', 'Los sitios de Chile', '0', '1905', 0, 0)
# ('tt0000532', 'short', 'Torrero y la ribera (Calles y plazas de Zaragoza)', 'Torrero y la ribera (Calles y plazas de Zaragoza)', '0', '1905', 0, 0)
# ('tt0000533', 'short', 'The Wooing and Wedding of a Coon', 'The Wooing and Wedding of a Coon', '0', '1907', 0, 0)
# ('tt0000534', 'short', "The '?' Motorist", "The '?' Motorist", '0', '1906', 0, '3')
# ('tt0000535', 'short', "The Anarchist's Mother-in-Law", 'Anarkistens svigermor', '0', '1906', 0, '4')
# ('tt0000536', 'short', 'Apachentanz', 'Apachentanz', '0', '1906', 0, '6')
# ('tt0000537', 'short', 'Arrival of Immigrants, Ellis Island', 'Arrival of Immigrants, Ellis Island', '0', '1906', 0, '4')
# ('tt0000538', 'short', 'Bilbao, Portugalete y los Altos Hornos', 'Bilbao, Portugalete y los Altos Hornos', '0', '1906', 0, 0)
# ('tt0000539', 'short', 'Bonden i København', 'Bonden i København', '0', '1906', 0, 0)
# ('tt0000540', 'short', 'Branden i Frihavnen', 'Branden i Frihavnen', '0', '1906', 0, 0)
# ('tt0000541', 'short', 'Caros død', 'Caros død', '0', '1906', 0, '6')
# ('tt0000542', 'short', 'Cerveza gratis', 'Cerveza gratis', '0', '1906', 0, '7')
# ('tt0000543', 'short', 'Christian IXS bisættelse', 'Christian IXS bisættelse', '0', '1906', 0, '15')
# ('tt0000544', 'short', "The Dancer's Dream", "The Dancer's Dream", '0', '1906', 0, 0)
# ('tt0000545', 'short', 'Dream of a Racetrack Fiend', 'Dream of a Racetrack Fiend', '0', '1906', 0, 0)
# ('tt0000546', 'short', 'Dream of a Rarebit Fiend', 'Dream of a Rarebit Fiend', '0', '1906', 0, '7')
# ('tt0000547', 'short', 'Ferias en San Sebastián y Cabalgata en la Ría', 'Ferias en San Sebastián y Cabalgata en la Ría', '0', '1906', 0, 0)
# ('tt0000548', 'short', 'Fiskerliv i Norden', 'Fiskerliv i Norden', '0', '1906', 0, 0)
# ('tt0000549', 'short', 'En foræring til min Kone', 'En foræring til min Kone', '0', '1906', 0, 0)
# ('tt0000550', 'short', 'Proklamationen af Kong Frederik d. VIII', 'Proklamationen af Kong Frederik d. VIII', '0', '1906', 0, '3')
# ('tt0000551', 'short', 'Fæstningskrigen', 'Fæstningskrigen', '0', '1906', 0, 0)
# ('tt0000552', 'short', 'The Hand of the Artist', 'The Hand of the Artist', '0', '1907', 0, 0)
# ('tt0000553', 'short', 'The Haunted Hotel', 'The Haunted Hotel', '0', '1907', 0, '5')
# ('tt0000554', 'short', 'Humorous Phases of Funny Faces', 'Humorous Phases of Funny Faces', '0', '1906', 0, '3')
# ('tt0000555', 'short', 'Den hvide slavinde', 'Den hvide slavinde', '0', '1907', 0, '7')
# ('tt0000556', 'short', 'Hævnet', 'Hævnet', '0', '1907', 0, 0)
# ('tt0000557', 'short', 'Kathleen Mavourneen', 'Kathleen Mavourneen', '0', '1906', 0, '15')
# ('tt0000558', 'short', 'Los kikos', 'Los kikos', '0', '1906', 0, 0)
# ('tt0000559', 'short', 'Konfirmanden', 'Konfirmanden', '0', '1906', 0, '3')
# ('tt0000560', 'short', 'Ladrones burlados', 'Ladrones burlados', '0', '1906', 0, 0)
# ('tt0000561', 'short', 'The Life of a Cowboy', 'The Life of a Cowboy', '0', '1906', 0, '13')
# ('tt0000562', 'short', 'Os Lusíadas', 'Os Lusíadas', '0', '1906', 0, 0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-0c20e40b0e25> in <module>
#      27
#      28     curs.execute(sql,data)
# ---> 29     conn.commit()
#      30 f.close()
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pymysql\connections.py in commit(self)
#     468         """
#     469         self._execute_command(COMMAND.COM_QUERY, "COMMIT")
# --> 470         self._read_ok_packet()
#     471
#     472     def rollback(self):
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pymysql\connections.py in _read_ok_packet(self)
#     441
#     442     def _read_ok_packet(self):
# --> 443         pkt = self._read_packet()
#     444         if not pkt.is_ok_packet():
#     445             raise err.OperationalError(2014, "Command Out of Sync")
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     690         buff = bytearray()
#     691         while True:
# --> 692             packet_header = self._read_bytes(4)
#     693             # if DEBUG: dump_packet(packet_header)
#     694
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pymysql\connections.py in _read_bytes(self, num_bytes)
#     730         while True:
#     731             try:
# --> 732                 data = self._rfile.read(num_bytes)
#     733                 break
#     734             except (IOError, OSError) as e:
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:
