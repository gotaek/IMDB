# %%
import csv
import pymysql

# %%
f = open('title.basics.tsv', 'r', encoding='utf=8')
rd = csv.reader(f, delimiter='\t')

conn=pymysql.connect(host='localhost',user='gotaek',password='gotaek',db='IMDB')
curs=conn.cursor(pymysql.cursors.DictCursor)

sql="insert ignore into works (workId,titleType,primaryTitle,originalTitle,isAdult,startYear,endYear,runtimeMinutes) values(%s,%s,%s,%s,%s,%s,%s,%s)"
for line in rd:
    isAdult=line[4]
    startYear=line[5]
    endYear=line[6]
    runtimeMinutes=line[7]
    for i in range(4,8):
        if line[4]!="0":
            isAdult=1
        if line[5]=="\\N":
            startYear=0
        if line[6]=="\\N":
            endYear=0
        if line[7]=="\\N":
            runtimeMinutes=0
    data=(line[0],line[1],line[2],line[3],isAdult,startYear,endYear,runtimeMinutes)
    print(data)
    
    curs.execute(sql,data)
    conn.commit()
f.close()
# Out:
# 909', 0, 0)
# ('tt0000873', 'short', 'Bakchisarayskiy fontan', 'Bakchisarayskiy fontan', '0', '1909', 0, 0)
# ('tt0000874', 'short', 'The French Duel', 'The French Duel', '0', '1909', 0, '4')
# ('tt0000875', 'short', 'The Friend of the Family', 'The Friend of the Family', '0', '1909', 0, '8')
# ('tt0000876', 'short', 'Fuss and Feathers', 'Fuss and Feathers', '0', '1909', 0, 0)
# ('tt0000877', 'short', 'Getting Even', 'Getting Even', '0', '1909', 0, '6')
# ('tt0000878', 'short', 'The Gibson Goddess', 'The Gibson Goddess', '0', '1909', 0, '6')
# ('tt0000879', 'movie', 'Gira política de Madero y Pino Suárez', 'Gira política de Madero y Pino Suárez', '0', '1909', 0, 0)
# ('tt0000880', 'short', 'The Girls and Daddy', 'The Girls and Daddy', '0', '1909', 0, '15')
# ('tt0000881', 'short', 'Le glas du père Césaire', 'Le glas du père Césaire', '0', '1909', 0, 0)
# ('tt0000882', 'short', 'The Golden Louis', 'The Golden Louis', '0', '1909', 0, '5')
# ('tt0000883', 'short', 'The Grey Lady', 'Den graa dame', '0', '1909', 0, '14')
# ('tt0000884', 'short', 'The Red Domino', 'Grevinde X', '0', '1909', 0, 0)
# ('tt0000885', 'short', 'Guzmán el Bueno', 'Guzmán el Bueno', '0', '1909', 0, '19')
# ('tt0000886', 'movie', 'Hamlet, Prince of Denmark', 'Hamlet', '0', '1910', 0, 0)
# ('tt0000887', 'short', 'Hansel and Gretel', 'Hansel and Gretel', '0', '1909', 0, 0)
# ('tt0000888', 'short', 'The Heart of a Clown', 'The Heart of a Clown', '0', '1909', 0, 0)
# ('tt0000889', 'short', 'The Heart of a Cowboy', 'The Heart of a Cowboy', '0', '1909', 0, 0)
# ('tt0000890', 'short', 'The Heart of an Outlaw', 'The Heart of an Outlaw', '0', '1909', 0, 0)
# ('tt0000891', 'short', 'Cycle Rider and the Witch', 'Heksen og cyklisten', '0', '1909', 0, '3')
# ('tt0000892', 'short', 'Her First Biscuits', 'Her First Biscuits', '0', '1909', 0, '6')
# ('tt0000893', 'short', 'Her Indian Hero', 'Her Indian Hero', '0', '1912', 0, 0)
# ('tt0000894', 'short', "The Farmer's Grandson", 'Herremandens Barnebarn', '0', '1909', 0, 0)
# ('tt0000895', 'short', 'The Hessian Renegades', 'The Hessian Renegades', '0', '1909', 0, '10')
# ('tt0000896', 'short', 'The Hindoo Dagger', 'The Hindoo Dagger', '0', '1909', 0, '10')
# ('tt0000897', 'short', 'His Duty', 'His Duty', '0', '1909', 0, '5')
# ('tt0000898', 'short', 'His Lost Love', 'His Lost Love', '0', '1909', 0, '11')
# ('tt0000899', 'short', 'His Reformation', 'His Reformation', '0', '1909', 0, 0)
# ('tt0000900', 'short', "His Ward's Love", "His Ward's Love", '0', '1909', 0, '3')
# ('tt0000901', 'short', "His Wife's Mother", "His Wife's Mother", '0', '1909', 0, '6')
# ('tt0000902', 'short', "His Wife's Visitor", "His Wife's Visitor", '0', '1909', 0, '6')
# ('tt0000903', 'short', 'The Honor of Thieves', 'The Honor of Thieves', '0', '1909', 0, '11')
# ('tt0000904', 'short', 'The House of Cards', 'The House of Cards', '0', '1909', 0, '16')
# ('tt0000905', 'short', 'I Did It', 'I Did It', '0', '1909', 0, '4')
# ('tt0000906', 'short', 'The Idiot of the Mountains', 'The Idiot of the Mountains', '0', '1909', 0, 0)
# ('tt0000907', 'short', 'In Little Italy', 'In Little Italy', '0', '1909', 0, '10')
# ('tt0000908', 'short', 'In Old Kentucky', 'In Old Kentucky', '0', '1909', 0, '11')
# ('tt0000909', 'short', 'In a Hempen Bag', 'In a Hempen Bag', '0', '1909', 0, '5')
# ('tt0000910', 'short', 'In the Watches of the Night', 'In the Watches of the Night', '0', '1909', 0, '11')
# ('tt0000911', 'short', 'In the Window Recess', 'In the Window Recess', '0', '1909', 0, '4')
# ('tt0000912', 'short', "The Indian Runner's Romance", "The Indian Runner's Romance", '0', '1909', 0, '11')
# ('tt0000913', 'short', 'The Indian Trailer', 'The Indian Trailer', '0', '1909', 0, 0)
# ('tt0000914', 'short', 'Industria del corcho', 'Industria del corcho', '0', '1909', 0, '7')
# ('tt0000915', 'short', 'Jailbird in Borrowed Feathers', 'Jailbird in Borrowed Feathers', '0', '1910', 0, 0)
# ('tt0000916', 'short', 'Je voudrais un enfant', 'Je voudrais un enfant', '0', '1910', 0, '6')
# ('tt0000917', 'short', 'Jealousy and the Man', 'Jealousy and the Man', '0', '1909', 0, '5')
# ('tt0000918', 'short', 'Jessie, the Stolen Child', 'Jessie, the Stolen Child', '0', '1909', 0, 0)
# ('tt0000919', 'short', 'The Jilt', 'The Jilt', '0', '1909', 0, '11')
# ('tt0000920', 'short', 'Jones and His New Neighbors', 'Jones and His New Neighbors', '0', '1909', 0, '5')
# ('tt0000921', 'short', 'Jones and the Lady Book Agent', 'Jones and the Lady Book Agent', '0', '1909', 0, '6')
# ('tt0000922', 'short', 'The Joneses Have Amateur Theatricals', 'The Joneses Have Amateur Theatricals', '0', '1909', 0, '4')
# ('tt0000923', 'short', 'El joyero', 'El joyero', '0', '1909', 0, 0)
# ('tt0000924', 'short', 'A Bad Case', 'Les joyeux microbes', '0', '1909', 0, '5')
# ('tt0000925', 'short', 'Judgment', 'Judgment', '0', '1909', 0, 0)
# ('tt0000926', 'short', 'Justicia de Felipe II', 'Justicia de Felipe II', '0', '1909', 0, 0)
# ('tt0000927', 'short', 'Kinemacolor Puzzle', 'Kinemacolor Puzzle', '0', '1909', 0, 0)
# ('tt0000928', 'short', 'King Lear', 'King Lear', '0', '1909', 0, '16')
# ('tt0000929', 'short', 'Klebolin klebt alles', 'Klebolin klebt alles', '0', '1909', 0, 0)
# ('tt0000930', 'short', 'Der kleine Detektiv', 'Der kleine Detektiv', '0', '1909', 0, 0)
# ('tt0000931', 'short', 'Dødsspringet', 'Dødsspringet', '0', '1910', 0, 0)
# ('tt0000932', 'short', 'A Woman of the People', 'En kvinde af folket', '0', '1909', 0, 0)
# ('tt0000933', 'short', "Lady Helen's Escapade", "Lady Helen's Escapade", '0', '1909', 0, '8')
# ('tt0000934', 'short', 'Leather Stocking', 'Leather Stocking', '0', '1909', 0, '11')
# ('tt0000935', 'short', 'The Light That Came', 'The Light That Came', '0', '1909', 0, '11')
# ('tt0000936', 'short', 'Lines of White on a Sullen Sea', 'Lines of White on a Sullen Sea', '0', '1909', 0, '11')
# ('tt0000938', 'short', 'The Little Darling', 'The Little Darling', '0', '1909', 0, '2')
# ('tt0000939', 'short', 'The Little Teacher', 'The Little Teacher', '0', '1909', 0, '11')
# ('tt0000940', 'short', 'Lochinvar', 'Lochinvar', '0', '1909', 0, 0)
# ('tt0000941', 'movie', 'Locura de amor', 'Locura de amor', '0', '1909', 0, 0)
# ('tt0000942', 'short', 'The Lonely Villa', 'The Lonely Villa', '0', '1909', 0, '8')
# ('tt0000943', 'short', 'Love Finds a Way', 'Love Finds a Way', '0', '1909', 0, '5')
# ('tt0000944', 'short', 'The Luck of the Cards', 'The Luck of the Cards', '0', '1909', 0, 0)
# ('tt0000945', 'short', 'Lucky Jim', 'Lucky Jim', '0', '1909', 0, '5')
# ('tt0000946', 'short', 'The Lure of the Gown', 'The Lure of the Gown', '0', '1909', 0, '6')
# ('tt0000947', 'movie', 'Lægens offer', 'Lægens offer', '0', '1909', 0, 0)
# ('tt0000948', 'short', "La légende de l'arc-en-ciel", "La légende de l'arc-en-ciel", '0', '1909', 0, 0)
# ('tt0000949', 'short', 'Det løbske gasrør', 'Det løbske gasrør', '0', '1909', 0, 0)
# ('tt0000950', 'short', 'Macbeth', 'Macbeth', '0', '1909', 0, 0)
# ('tt0000951', 'short', 'Madam Sans Gene; or, The Duchess of Danzig', 'Madame Sans-Gêne', '0', '1909', 0, 0)
# ('tt0000952', 'short', 'Madame de Langeais', 'Madame de Langeais', '0', '1910', 0, '7')
# ('tt0000953', 'short', 'A Maid of the Mountains', 'A Maid of the Mountains', '0', '1909', 0, 0)
# ('tt0000954', 'short', 'Mamma', 'Mamma', '0', '1909', 0, 0)
# ('tt0000955', 'short', 'A Man with Three Wives', 'A Man with Three Wives', '0', '1909', 0, 0)
# ('tt0000956', 'short', 'The Maniac Cook', 'The Maniac Cook', '0', '1909', 0, '9')
# ('tt0000957', 'short', 'Mariage forcé', 'Mariage forcé', '0', '1914', 0, '20')
# ('tt0000958', 'short', 'The Medicine Bottle', 'The Medicine Bottle', '0', '1909', 0, '5')
# ('tt0000959', 'movie', 'Melilla y el Gurugu', 'Melilla y el Gurugu', '0', '1909', 0, 0)
# ('tt0000960', 'short', 'The Mended Lute', 'The Mended Lute', '0', '1909', 0, '11')
# ('tt0000961', 'short', 'The Message', 'The Message', '0', '1909', 0, '10')
# ('tt0000962', 'short', 'The Mexican Sweethearts', 'The Mexican Sweethearts', '0', '1909', 0, '3')
# ('tt0000963', 'short', "A Mexican's Gratitude", "A Mexican's Gratitude", '0', '1909', 0, 0)
# ('tt0000964', 'short', 'A Midnight Adventure', 'A Midnight Adventure', '0', '1909', 0, '6')
# ('tt0000965', 'short', 'Midnight Disturbance', 'Midnight Disturbance', '0', '1909', 0, 0)
# ('tt0000966', 'short', "A Midsummer Night's Dream", "A Midsummer Night's Dream", '0', '1909', 0, '12')
# ('tt0000967', 'short', 'The Mills of the Gods', 'The Mills of the Gods', '0', '1909', 0, '7')
# ('tt0000968', 'short', 'Mistaken Identity', 'Mistaken Identity', '0', '1909', 0, 0)
# ('tt0000969', 'short', 'Les Misérables', 'Les Misérables', '0', '1909', 0, '44')
# ('tt0000970', 'short', 'The Life of Moliere', 'Molière', '0', '1910', 0, 0)
# ('tt0000971', 'short', 'The Mill', 'Le Moulin maudit', '0', '1909', 0, '6')
# ('tt0000972', 'short', "The Mountaineer's Honor", "The Mountaineer's Honor", '0', '1909', 0, '11')
# ('tt0000974', 'short', 'Mr. Jones Has a Card Party', 'Mr. Jones Has a Card Party', '0', '1909', 0, '10')
# ('tt0000975', 'short', "Mr. Jones' Burglar", "Mr. Jones' Burglar", '0', '1909', 0, '4')
# ('tt0000976', 'short', "Mrs. Jones' Lover; or, 'I Want My Hat'", "Mrs. Jones' Lover; or, 'I Want My Hat'", '0', '1909', 0, '5')
# ('tt0000977', 'short', 'Mutterliebe', 'Mutterliebe', '0', '1909', 0, 0)
# ('tt0000978', 'short', 'Napoleon og hans lille Trompetist', 'Napoleon og hans lille Trompetist', '0', '1909', 0, 0)
# ('tt0000979', 'short', 'Napoleon, the Man of Destiny', 'Napoleon, the Man of Destiny', '0', '1908', 0, 0)
# ('tt0000980', 'short', 'A Narrow Escape from Lynching', 'A Narrow Escape from Lynching', '0', '1909', 0, 0)
# ('tt0000981', 'short', 'The Necklace', 'The Necklace', '0', '1909', 0, '11')
# ('tt0000982', 'short', 'The New Servant', 'The New Servant', '0', '1909', 0, 0)
# ('tt0000983', 'short', 'A New Trick', 'A New Trick', '0', '1909', 0, '2')
# ('tt0000984', 'movie', 'Niños en la alameda', 'Niños en la alameda', '0', '1909', 0, 0)
# ('tt0000985', 'short', 'The Note in the Shoe', 'The Note in the Shoe', '0', '1909', 0, '8')
# ('tt0000986', 'short', 'Nursing a Viper', 'Nursing a Viper', '0', '1909', 0, '10')
# ('tt0000987', 'short', 'How Brother Cook was Taught a Lesson', 'Naar Djævle er paa Spil', '0', '1910', 0, 0)
# ('tt0000988', 'short', 'The Short-Sighted Governess', 'Den nærsynede guvernante', '0', '1909', 0, '2')
# ('tt0000989', 'short', 'Oh, Uncle!', 'Oh, Uncle!', '0', '1909', 0, '3')
# ('tt0000990', 'short', 'Oliver Twist', 'Oliver Twist', '0', '1909', 0, '14')
# ('tt0000991', 'short', "On the Little Big Horn or Custer's Last Stand", "On the Little Big Horn or Custer's Last Stand", '0', '1909', 0, 0)
# ('tt0000992', 'movie', 'De onde Veje', 'De onde Veje', '0', '1909', 0, 0)
# ('tt0000993', 'short', 'One Busy Hour', 'One Busy Hour', '0', '1909', 0, '3')
# ('tt0000994', 'short', 'One Good Turn Deserves Another', 'One Good Turn Deserves Another', '0', '1909', 0, 0)
# ('tt0000995', 'short', 'One Touch of Nature', 'One Touch of Nature', '0', '1909', 0, '10')
# ('tt0000996', 'short', 'Only a Tramp', 'Only a Tramp', '0', '1909', 0, 0)
# ('tt0000997', 'short', 'The Open Gate', 'The Open Gate', '0', '1909', 0, '11')
# ('tt0000998', 'short', 'Othello', 'Otello', '0', '1909', 0, '12')
# ('tt0000999', 'short', "Paul Wang's Destiny", 'Paul Wangs skæbne', '0', '1909', 0, 0)
# ('tt0001000', 'short', 'The Peachbasket Hat', 'The Peachbasket Hat', '0', '1909', 0, '7')
# ('tt0001001', 'short', 'Pippa Passes; or, The Song of Conscience', 'Pippa Passes; or, The Song of Conscience', '0', '1909', 0, '11')
# ('tt0001002', 'short', "The Politician's Love Story", "The Politician's Love Story", '0', '1909', 0, '6')
# ('tt0001003', 'short', 'Por un ratón', 'Por un ratón', '0', '1909', 0, '8')
# ('tt0001004', 'short', 'Portrait of Mireille', 'Le portrait de Mireille', '0', '1909', 0, '8')
# ('tt0001005', 'short', 'Pranks', 'Pranks', '0', '1909', 0, '4')
# ('tt0001006', 'short', "Primera carrera internacional de automóviles 'Peña-Rhin'", "Primera carrera internacional de automóviles 'Peña-Rhin'", '0', '1909', 0, '10')
# ('tt0001007', 'movie', 'La primera y segunda casetas', 'La primera y segunda casetas', '0', '1909', 0, 0)
# ('tt0001008', 'short', 'The Prince and the Pauper', 'The Prince and the Pauper', '0', '1909', 0, 0)
# ('tt0001009', 'short', 'Princess Nicotine; or, The Smoke Fairy', 'Princess Nicotine; or, The Smoke Fairy', '0', '1909', 0, '5')
# ('tt0001010', 'movie', 'Protección de un convoy de víveres en el puente de camellos', 'Protección de un convoy de víveres en el puente de camellos', '0', '1909', 0, 0)
# ('tt0001011', 'short', 'The Prussian Spy', 'The Prussian Spy', '0', '1909', 0, '5')
# ('tt0001012', 'short', "The Ranchman's Rival", "The Ranchman's Rival", '0', '1909', 0, 0)
# ('tt0001013', 'short', "The Redman's View", "The Redman's View", '0', '1909', 0, '14')
# ('tt0001014', 'short', 'The Renunciation', 'The Renunciation', '0', '1909', 0, '11')
# ('tt0001015', 'short', 'The Restoration', 'The Restoration', '0', '1909', 0, '10')
# ('tt0001016', 'short', 'Resurrection', 'Resurrection', '0', '1909', 0, '12')
# ('tt0001017', 'short', 'A Wedding During the French Revolution', 'Revolutionsbryllup', '0', '1910', 0, 0)
# ('tt0001018', 'short', 'Richelieu; or: The Conspiracy', 'Richelieu; or: The Conspiracy', '0', '1910', 0, 0)
# ('tt0001019', 'short', 'The Road Agents', 'The Road Agents', '0', '1909', 0, 0)
# ('tt0001020', 'short', 'The Road to the Heart', 'The Road to the Heart', '0', '1909', 0, '7')
# ('tt0001021', 'short', 'Robbing the Widowed and Fatherless', 'Robbing the Widowed and Fatherless', '0', '1909', 0, 0)
# ('tt0001022', 'short', 'A Rose of the Tenderloin', 'A Rose of the Tenderloin', '0', '1909', 0, 0)
# ('tt0001023', 'short', "The Roue's Heart", "The Roue's Heart", '0', '1909', 0, '8')
# ('tt0001024', 'short', 'A Rude Hostess', 'A Rude Hostess', '0', '1909', 0, '5')
# ('tt0001025', 'short', 'A Rural Elopement', 'A Rural Elopement', '0', '1909', 0, '9')
# ('tt0001026', 'short', 'Ruy Blas', 'Ruy Blas', '0', '1909', 0, 0)
# ('tt0001027', 'short', 'The Sacrifice', 'The Sacrifice', '0', '1909', 0, '7')
# ('tt0001028', 'movie', 'Salome Mad', 'Salome Mad', '0', '1909', 0, 0)
# ('tt0001029', 'short', 'The Salvation Army Lass', 'The Salvation Army Lass', '0', '1909', 0, '15')
# ('tt0001030', 'short', 'Saul and David', 'Saul and David', '0', '1909', 0, '10')
# ('tt0001031', 'short', "Schneider's Anti-Noise Crusade", "Schneider's Anti-Noise Crusade", '0', '1909', 0, 0)
# ('tt0001032', 'short', 'The Sealed Room', 'The Sealed Room', '0', '1909', 0, '11')
# ('tt0001033', 'short', 'The Seventh Day', 'The Seventh Day', '0', '1909', 0, '8')
# ('tt0001034', 'short', 'Shanghaied', 'Shanghaied', '0', '1909', 0, 0)
# ('tt0001035', 'short', 'She Would Be an Actress', 'She Would Be an Actress', '0', '1909', 0, '5')
# ('tt0001036', 'short', 'Sherlock Holmes IV', 'Sherlock Holmes IV', '0', '1909', 0, 0)
# ('tt0001037', 'short', 'Sherlock Holmes V', 'Sherlock Holmes V', '0', '1909', 0, 0)
# ('tt0001038', 'movie', 'Sherlock Holmes VI', 'Sherlock Holmes VI', '0', '1910', 0, 0)
# ('tt0001039', 'short', "A Sinner's Repentance", "A Sinner's Repentance", '0', '1909', 0, 0)
# ('tt0001040', 'short', "A Sister's Love: A Tale of the Franco-Prussian War", "A Sister's Love: A Tale of the Franco-Prussian War", '0', '1909', 0, 0)
# ('tt0001041', 'short', 'The Slave', 'The Slave', '0', '1909', 0, '11')
# ('tt0001042', 'short', 'The Sleepwalker', 'The Sleepwalker', '0', '1909', 0, 0)
# ('tt0001043', 'movie', "Smith's Knockabout Theatre", "Smith's Knockabout Theatre", '0', '1909', 0, 0)
# ('tt0001044', 'short', "The Son's Return", "The Son's Return", '0', '1909', 0, '11')
# ('tt0001045', 'short', "Le songe d'une nuit d'été", "Le songe d'une nuit d'été", '0', '1910', 0, '11')
# ('tt0001046', 'short', 'A Sound Sleeper', 'A Sound Sleeper', '0', '1909', 0, '2')
# ('tt0001047', 'short', 'The Spanish Girl', 'The Spanish Girl', '0', '1909', 0, 0)
# ('tt0001048', 'short', 'The Special License', 'The Special Licence', '0', '1909', 0, 0)
# ('tt0001049', 'movie', 'Gøngehøvdingen', 'Gøngehøvdingen', '0', '1909', 0, 0)
# ('tt0001050', 'short', 'A Strange Meeting', 'A Strange Meeting', '0', '1909', 0, '11')
# ('tt0001051', 'movie', 'El sueño milagroso', 'El sueño milagroso', '0', '1909', 0, 0)
# ('tt0001052', 'short', 'The Suicide Club', 'The Suicide Club', '0', '1909', 0, '4')
# ('tt0001053', 'short', 'A Sweet Revenge', 'A Sweet Revenge', '0', '1909', 0, '5')
# ('tt0001054', 'short', 'Sweet and Twenty', 'Sweet and Twenty', '0', '1909', 0, '6')
# ('tt0001055', 'short', 'A Tale of the West', 'A Tale of the West', '0', '1909', 0, 0)
# ('tt0001056', 'short', 'Teaching a Husband a Lesson', 'Teaching a Husband a Lesson', '0', '1909', 0, 0)
# ('tt0001057', 'short', 'Ten Nights in a Barroom', 'Ten Nights in a Barroom', '0', '1909', 0, 0)
# ('tt0001058', 'short', 'Tender Hearts', 'Tender Hearts', '0', '1909', 0, '8')
# ('tt0001059', 'movie', 'O Terremoto de Benavente', 'O Terremoto de Benavente', '0', '1909', 0, 0)
# ('tt0001060', 'short', 'The Test', 'The Test', '0', '1909', 0, '6')
# ('tt0001061', 'short', 'They Would Elope', 'They Would Elope', '0', '1909', 0, '6')
# ('tt0001062', 'short', 'Those Awful Hats', 'Those Awful Hats', '0', '1909', 0, '2')
# ('tt0001063', 'short', 'Those Boys!', 'Those Boys!', '0', '1909', 0, '4')
# ('tt0001064', 'short', 'Through the Breakers', 'Through the Breakers', '0', '1909', 0, '11')
# ('tt0001065', 'short', 'Tis an Ill Wind That Blows No Good', 'Tis an Ill Wind That Blows No Good', '0', '1909', 0, '10')
# ('tt0001066', 'short', 'De to guldgravere', 'De to guldgravere', '0', '1909', 0, 0)
# ('tt0001067', 'short', 'To Save Her Soul', 'To Save Her Soul', '0', '1909', 0, '11')
# ('tt0001068', 'short', 'Toma caseta Z', 'Toma caseta Z', '0', '1909', 0, 0)
# ('tt0001069', 'movie', 'Toma del Gurugu', 'Toma del Gurugu', '0', '1909', 0, 0)
# ('tt0001070', 'short', 'Tragedia torera', 'Tragedia torera', '0', '1909', 0, '14')
# ('tt0001071', 'short', 'Tragic Love', 'Tragic Love', '0', '1909', 0, '15')
# ('tt0001072', 'short', 'A Trap for Santa Claus', 'A Trap for Santa Claus', '0', '1909', 0, '16')
# ('tt0001073', 'short', 'The Treacherous Policeman', 'The Treacherous Policeman', '0', '1909', 0, 0)
# ('tt0001074', 'short', 'The Trick That Failed', 'The Trick That Failed', '0', '1909', 0, '7')
# ('tt0001075', 'short', 'A Troublesome Satchel', 'A Troublesome Satchel', '0', '1909', 0, '2')
# ('tt0001076', 'short', 'Trying to Get Arrested', 'Trying to Get Arrested', '0', '1909', 0, '4')
# ('tt0001077', 'short', 'Twin Brothers', 'Twin Brothers', '0', '1909', 0, '5')
# ('tt0001078', 'short', 'Two Memories', 'Two Memories', '0', '1909', 0, '3')
# ('tt0001079', 'short', 'Two Women and a Man', 'Two Women and a Man', '0', '1909', 0, '11')
# ('tt0001080', 'movie', 'Two of the Boys', 'Two of the Boys', '0', '1909', 0, 0)
# ('tt0001081', 'movie', 'La vida en el campamento', 'La vida en el campamento', '0', '1909', 0, 0)
# ('tt0001082', 'movie', 'Viernes de dolores', 'Viernes de dolores', '0', '1909', 0, 0)
# ('tt0001083', 'short', 'The Violin Maker of Cremona', 'The Violin Maker of Cremona', '0', '1909', 0, '10')
# ('tt0001084', 'short', 'The Voice of the Violin', 'The Voice of the Violin', '0', '1909', 0, '16')
# ('tt0001085', 'short', 'Wanted, a Child', 'Wanted, a Child', '0', '1909', 0, '3')
# ('tt0001086', 'short', 'Was Justice Served?', 'Was Justice Served?', '0', '1909', 0, '10')
# ('tt0001087', 'short', 'Washington Under the American Flag', 'Washington Under the American Flag', '0', '1909', 0, 0)
# ('tt0001088', 'short', 'The Way of Man', 'The Way of Man', '0', '1909', 0, '11')
# ('tt0001089', 'short', 'We Must Do Our Best', 'We Must Do Our Best', '0', '1909', 0, '10')
# ('tt0001090', 'short', 'The Welcome Burglar', 'The Welcome Burglar', '0', '1909', 0, '13')
# ('tt0001091', 'short', 'What Drink Did', 'What Drink Did', '0', '1909', 0, '12')
# ('tt0001092', 'short', "What's Your Hurry?", "What's Your Hurry?", '0', '1909', 0, '4')
# ('tt0001093', 'short', 'When Thieves Fall Out', 'When Thieves Fall Out', '0', '1909', 0, 0)
# ('tt0001094', 'short', 'The Winning Coat', 'The Winning Coat', '0', '1909', 0, '8')
# ('tt0001095', 'short', 'With Her Card', 'With Her Card', '0', '1909', 0, '11')
# ('tt0001096', 'short', 'Within an Ace', 'Within an Ace', '0', '1909', 0, 0)
# ('tt0001097', 'short', "A Woman's Vanity", "A Woman's Vanity", '0', '1909', 0, 0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-e7de9c0ced19> in <module>
#      24
#      25     curs.execute(sql,data)
# ---> 26     conn.commit()
#      27 f.close()
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pymysql\connections.py in commit(self)
#     468         """
#     469         self._execute_command(COMMAND.COM_QUERY, "COMMIT")
# --> 470         self._read_ok_packet()
#     471
#     472     def rollback(self):
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pymysql\connections.py in _read_ok_packet(self)
#     441
#     442     def _read_ok_packet(self):
# --> 443         pkt = self._read_packet()
#     444         if not pkt.is_ok_packet():
#     445             raise err.OperationalError(2014, "Command Out of Sync")
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     690         buff = bytearray()
#     691         while True:
# --> 692             packet_header = self._read_bytes(4)
#     693             # if DEBUG: dump_packet(packet_header)
#     694
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pymysql\connections.py in _read_bytes(self, num_bytes)
#     730         while True:
#     731             try:
# --> 732                 data = self._rfile.read(num_bytes)
#     733                 break
#     734             except (IOError, OSError) as e:
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:
