# %%
import pymysql
import csv

# %%
f = open('name.basics.tsv', 'r', encoding='utf=8')
rd = csv.reader(f, delimiter='\t')

conn=pymysql.connect(host='localhost',user='gotaek',password='gotaek',db='IMDB')
curs=conn.cursor(pymysql.cursors.DictCursor)

sql="insert ignore into actor (actorId,primaryName,birthYear,deathYear) values(%s,%s,%s,%s)"
next(rd)
rows=[]
i=0
for line in rd:
    if "actor" in line[4] or "actress" in line[4]:
        a=line[2] if line[2]!="\\N" else "0"
        b=line[3] if line[3] !="\\N" else "0"
        data=(line[0],line[1],a,b)

        rows.append(data)
        i+=1
    if i%1000==0:
        curs.excutemany(sql,rows)
        conn.comiit()
        rows=[]
        print("%d row"%i)
if rows:
    curs.executemany(sql,rows)
    conn.commit()
    print("%d rows"%i)
    

f.close()
cur.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-893c87c9713a> in <module>
#      18         i+=1
#      19     if i%1000==0:
# ---> 20         curs.excutemany(sql,rows)
#      21         conn.comiit()
#      22         rows=[]
#
# AttributeError: 'DictCursor' object has no attribute 'excutemany'

# %%
f = open('name.basics.tsv', 'r', encoding='utf=8')
rd = csv.reader(f, delimiter='\t')

conn=pymysql.connect(host='localhost',user='gotaek',password='gotaek',db='IMDB')
curs=conn.cursor(pymysql.cursors.DictCursor)

sql="insert ignore into director (directorId,primaryName,birthYear,deathYear) values(%s,%s,%s,%s)"
next(rd)
for line in rd:
    
    if "director" in line[4] :
        a=line[2] if line[2]!="\\N" else '0'
        b=line[3] if line[3] !="\\N" else '0'
        data=(line[0],line[1],a,b )
    
        print(data)
        curs.execute(sql,data)
        conn.commit()

f.close()

# %%
f = open('name.basics.tsv', 'r', encoding='utf=8')
rd = csv.reader(f, delimiter='\t')

conn=pymysql.connect(host='localhost',user='gotaek',password='gotaek',db='IMDB')
curs=conn.cursor(pymysql.cursors.DictCursor)

sql="insert ignore into writer (writerId,primaryName,birthYear,deathYear) values(%s,%s,%s,%s)"
next(rd)
for line in rd:
    
    if "writer" in line[4] :
        a=line[2] if line[2]!="\\N" else '0'
        b=line[3] if line[3] !="\\N" else '0'
        data=(line[0],line[1],a,b )
    
        print(data)
        curs.execute(sql,data)
        conn.commit()

f.close()
# Out:
# Colin Birch', '0', '0')
# ('nm3554515', 'Mervyn Woodrow', '0', '0')
# ('nm3554518', 'John Somers', '0', '0')
# ('nm3554526', 'Kellen Playford', '1984', '0')
# ('nm3554537', 'Jillian Locke', '0', '0')
# ('nm3554549', 'Yong Zhang', '0', '0')
# ('nm3554565', 'Crystal Foster', '0', '0')
# ('nm3554569', 'Colin L. Racicot', '0', '0')
# ('nm3554575', 'Josh Leo', '0', '0')
# ('nm3554616', 'Kristina Thomas', '0', '0')
# ('nm3554636', 'Afonso Cruz', '0', '0')
# ('nm3554643', 'Olga Ryashina', '0', '0')
# ('nm3554655', 'Babette Ellen', '1975', '0')
# ('nm3554660', 'Daniel Ribas', '0', '0')
# ('nm3554668', 'Susan Hogue', '0', '0')
# ('nm3554679', 'Mike MacLean', '0', '0')
# ('nm3554680', 'Tony Perzow', '0', '0')
# ('nm3554712', 'Yves Hinant', '0', '0')
# ('nm3554747', 'Justin Warner', '1984', '0')
# ('nm3554748', 'Masahiko Shiraishi', '0', '0')
# ('nm3554749', 'Gabriella Giuliani', '0', '0')
# ('nm3554755', 'Jackson Low', '1982', '0')
# ('nm3554757', 'C.W. Winter', '0', '0')
# ('nm3554781', 'Alex Marx', '0', '0')
# ('nm3554784', 'Doug Aubrey', '0', '0')
# ('nm3554785', 'Levi Bailey', '0', '0')
# ('nm3554795', 'Abdulselam Kilgi', '0', '0')
# ('nm3554803', 'Emmanuel Abela', '0', '0')
# ('nm3554831', 'Pete Carboni', '0', '0')
# ('nm3554847', 'Prakash Baral', '0', '0')
# ('nm3554894', 'Hugh Hancock', '0', '0')
# ('nm3554909', 'Béatrice de Staël', '0', '0')
# ('nm3554929', 'Chelsea Matter', '0', '0')
# ('nm3554943', 'Ismael Caneppele', '0', '0')
# ('nm3554980', 'Henrique Larré', '1990', '0')
# ('nm3554990', 'Sean Horne', '0', '0')
# ('nm3554998', 'Monica Campagna', '0', '0')
# ('nm3555002', 'Antoni Pinent', '0', '0')
# ('nm3555049', 'Francesco Gatti', '0', '0')
# ('nm3555055', 'Carroll Keane', '0', '0')
# ('nm3555062', 'Cat Navarro Lee', '0', '0')
# ('nm3555069', 'William Mayo', '0', '0')
# ('nm3555106', 'Amin Bagheri', '0', '0')
# ('nm3555108', 'Lama Jinpa Gyamtso', '0', '0')
# ('nm3555135', 'R.S. Pandit', '0', '0')
# ('nm3555148', 'Lloyd Aur Norman', '0', '0')
# ('nm3555152', 'Anis Gharbi', '1977', '0')
# ('nm3555160', 'Molly Kelleher', '0', '0')
# ('nm3555192', 'Courtney Walker', '0', '0')
# ('nm3555198', 'Gyal Sonthar', '0', '0')
# ('nm3555204', 'Daniel Hoover', '0', '0')
# ('nm3555215', 'Urs Schnell', '0', '0')
# ('nm3555217', 'Manoj Tapadia', '0', '0')
# ('nm3555249', 'Igor Vuk Torbica', '1987', '2020')
# ('nm3555252', 'Aleksandr Kuschnarenko', '0', '0')
# ('nm3555258', 'Richard Pearce', '0', '0')
# ('nm3555261', 'Franz Schreker', '1878', '1934')
# ('nm3555267', 'Corina Dennison', '0', '0')
# ('nm3555270', 'Jamie Antonisse', '0', '0')
# ('nm3555273', 'Hongsen Zhang', '0', '0')
# ('nm3555287', 'Sabeen Amanat', '0', '0')
# ('nm3555303', 'Zdenka Novotni', '0', '0')
# ('nm3555305', 'Daniel Urbankowski', '0', '0')
# ('nm3555319', 'Robert de Saint-Jean', '1901', '1987')
# ('nm3555328', 'Matthew Hammett Knott', '0', '0')
# ('nm3555359', 'Oliver Mbamara', '0', '0')
# ('nm3555364', 'Tommy Heleringer', '0', '0')
# ('nm3555367', 'Marcelo Tolces', '0', '0')
# ('nm3555376', 'Kimberly Willming', '0', '0')
# ('nm3555410', 'Münire Bozdemir', '0', '0')
# ('nm3555420', 'Emmeke Boot', '0', '0')
# ('nm3555436', 'Michael David Marshall', '0', '0')
# ('nm3555445', 'Julia Barrett-Mitchell', '0', '0')
# ('nm3555450', 'Joe Arjona', '1983', '0')
# ('nm3555454', 'Adriana Calvo', '0', '0')
# ('nm3555486', 'Matthew King-Ringo', '0', '0')
# ('nm3555497', 'Mihalis Glyniadakis', '0', '0')
# ('nm3555500', 'Dushant Kirpalani', '1982', '0')
# ('nm3555504', 'Matthew Cohen', '0', '0')
# ('nm3555511', 'Graziela Sáenz de Heredia', '0', '0')
# ('nm3555558', 'James Roblin', '0', '0')
# ('nm3555584', 'Evridiki Sifnaiou', '0', '0')
# ('nm3555590', 'Opie Sayner-Hassall', '0', '0')
# ('nm3555596', 'Kinara Samael', '0', '0')
# ('nm3555607', 'Giorgos Panagiotakis', '0', '0')
# ('nm3555616', 'Chris Haynes', '0', '0')
# ('nm3555619', 'Alara Ceri', '0', '0')
# ('nm3555660', 'Adriana González-Vega', '0', '0')
# ('nm3555672', 'Jakub Lucius Roll', '0', '0')
# ('nm3555678', 'Joe Jestus', '0', '0')
# ('nm3555692', 'Diego Cirulo', '0', '0')
# ('nm3555722', 'Yan Widjaya', '0', '0')
# ('nm3555724', 'Linas Augutis', '0', '0')
# ('nm3555727', 'Justin Hall', '0', '0')
# ('nm3555728', 'Harvey Brownstone', '0', '0')
# ('nm3555758', 'Daryl Kane', '0', '0')
# ('nm3555786', 'Alexander Copper', '0', '0')
# ('nm3555800', 'J. Jackie Baier', '1955', '0')
# ('nm3555810', 'Laura Zaylea', '0', '0')
# ('nm3555830', 'Philippe Alexandre', '0', '0')
# ('nm3555833', 'Don Scime', '0', '0')
# ('nm3555844', 'Amy Hollenberg', '0', '0')
# ('nm3555848', 'François Grandjacques', '0', '0')
# ('nm3555851', 'Amber Price', '0', '0')
# ('nm3555853', 'Hisanori Shimizu', '0', '0')
# ('nm3555882', 'Rich Volin', '0', '0')
# ('nm3555909', 'Jessica M. Bair', '0', '0')
# ('nm3555926', 'Folke Renken', '1980', '0')
# ('nm3555941', 'Allan Traylor', '0', '0')
# ('nm3555945', 'Iannis Aliferis', '0', '0')
# ('nm3555959', 'Jeff Stein', '0', '0')
# ('nm3555973', 'Wolf Hermsen', '0', '0')
# ('nm3555988', 'Rick L. Pollack', '0', '0')
# ('nm3555992', 'Mikelle Virey', '0', '0')
# ('nm3555993', 'Dui Jarrod', '0', '0')
# ('nm3555995', 'Geoff Edgers', '0', '0')
# ('nm3556002', 'Géza Oberfrank', '1936', '2015')
# ('nm3556019', 'Max Robinson', '0', '0')
# ('nm3556038', 'Shirli Michalevicz', '0', '0')
# ('nm3556043', 'Jan Harloff', '0', '0')
# ('nm3556044', 'Henriette Valot', '0', '0')
# ('nm3556060', 'Paul Kuritz', '0', '0')
# ('nm3556086', 'Milivoj Matosec', '0', '0')
# ('nm3556096', 'John Broccolo', '0', '0')
# ('nm3556118', 'Tom Gatley', '0', '0')
# ('nm3556123', 'Maxime Midière', '0', '0')
# ('nm3556131', 'Juli Vallmitjana', '0', '0')
# ('nm3556151', 'Pt. Mahadevshastri Joshi', '0', '0')
# ('nm3556176', 'Michal Ogórek', '1955', '0')
# ('nm3556177', 'Edward Bear', '0', '0')
# ('nm3556184', 'Gerald Smith', '0', '0')
# ('nm3556203', 'Shelby Taylor', '0', '0')
# ('nm3556213', 'Tammy Sortor', '0', '0')
# ('nm3556217', 'Mari Mari Nerváez', '0', '0')
# ('nm3556225', 'Nishant Gogna', '0', '0')
# ('nm3556281', 'Margarita Sambani', '0', '0')
# ('nm3556306', 'Remo Bodei', '1938', '2019')
# ('nm3556335', 'Jeremy McTiernan', '0', '0')
# ('nm3556347', 'Carissa Kacmarek', '0', '0')
# ('nm3556366', 'Claudia Sarkany', '0', '0')
# ('nm3556396', 'Fanis Stamatiou', '0', '0')
# ('nm3556398', 'Teresa Fuillerat', '0', '0')
# ('nm3556399', 'Jeanne Scott', '0', '0')
# ('nm3556409', 'Harrison Bevins', '0', '0')
# ('nm3556414', 'Kathleen Kelly', '0', '0')
# ('nm3556415', 'Ryan G. Malleus', '0', '0')
# ('nm3556418', 'Mircea Bumbesti', '0', '0')
# ('nm3556426', 'T.J. Berrings', '0', '0')
# ('nm3556439', 'Adeline Anfray', '0', '0')
# ('nm3556457', 'Chris Lawson', '0', '0')
# ('nm3556463', 'Kelong Li', '0', '0')
# ('nm3556477', 'J. Seabreak', '0', '0')
# ('nm3556479', 'Ashley Rhodes-Courter', '1985', '0')
# ('nm3556503', 'Kathy Cook', '0', '0')
# ('nm3556514', 'Tasos Koliopoulos', '0', '0')
# ('nm3556515', 'Mike Stern', '0', '0')
# ('nm3556523', 'Veronica Cascelli', '0', '0')
# ('nm3556548', 'Michael Humphrey', '0', '0')
# ('nm3556568', 'Sebastián Badilla', '0', '0')
# ('nm3556572', 'Ryan Jordan', '0', '0')
# ('nm3556590', 'Federico Bravo Morata', '0', '0')
# ('nm3556602', 'Jonas Banys', '0', '0')
# ('nm3556607', 'Ryan Darbonne', '0', '0')
# ('nm3556627', 'Josep Tomàs Cabot', '0', '0')
# ('nm3556632', 'Tamara Bijelic', '1985', '0')
# ('nm3556639', 'Marta E. Vilaltella', '0', '0')
# ('nm3556655', 'Petros Koublis', '1979', '0')
# ('nm3556657', 'Aleka Boutzouvi', '0', '0')
# ('nm3556668', 'Joe Dever', '1956', '2016')
# ('nm3556677', 'Michael Leighton', '0', '0')
# ('nm3556691', 'Amy E. Sousa', '0', '0')
# ('nm3556692', 'Luc Fevrier-Silberman', '0', '0')
# ('nm3556713', 'Curtis Donarovich', '0', '0')
# ('nm3556724', 'Helena von Zweigbergk', '0', '0')
# ('nm3556730', 'E.J. Katz', '0', '0')
# ('nm3556760', 'Ace Masters', '0', '0')
# ('nm3556771', 'Sharon Skinner', '1952', '0')
# ('nm3556778', 'Miki Miyashita', '0', '0')
# ('nm3556784', 'Simon Constantine', '0', '0')
# ('nm3556791', 'Marcella Tamayo', '0', '0')
# ('nm3556794', 'Maxime Duguay', '0', '0')
# ('nm3556797', 'Rafe Gibbons', '0', '0')
# ('nm3556804', 'Masa Gibson', '0', '0')
# ('nm3556822', 'Suzanne Hope', '0', '0')
# ('nm3556861', 'Paul Jenner', '0', '0')
# ('nm3556869', 'Calum Smith', '0', '0')
# ('nm3556874', 'Brandon Pavon', '0', '0')
# ('nm3556981', 'Henderson Maddox', '0', '0')
# ('nm3556992', 'John Loper', '1983', '0')
# ('nm3557006', 'Gabbi Tuft', '1978', '0')
# ('nm3557018', 'Scott A. Cornell', '0', '0')
# ('nm3557036', 'Yau Lee', '0', '0')
# ('nm3557038', 'Kris Phipps', '0', '0')
# ('nm3557063', 'Karola Raimond', '0', '0')
# ('nm3557065', 'James Allred', '0', '0')
# ('nm3557070', 'Eeva Niinivaara', '0', '0')
# ('nm3557081', 'Tony Faust', '0', '0')
# ('nm3557084', 'Achim Neufeld', '0', '0')
# ('nm3557089', 'Mark Tracey', '0', '0')
# ('nm3557148', 'Emmanuel Jean', '0', '0')
# ('nm3557163', 'James Muller', '0', '0')
# ('nm3557170', 'Nolan Wilson Goff', '0', '0')
# ('nm3557176', 'Maureen Thomas', '0', '0')
# ('nm3557221', 'Surojit Chowdhury', '0', '0')
# ('nm3557229', 'Mario Giordano', '1966', '0')
# ('nm3557235', 'Eissa Burghed', '0', '0')
# ('nm3557291', 'Mark Grimmer', '0', '0')
# ('nm3557330', 'Simon Edi Shvarc', '0', '0')
# ('nm3557398', 'Michal Imielski', '0', '0')
# ('nm3557410', 'Katherine Sheyno', '0', '0')
# ('nm3557417', 'Hassan Abdulrazzak', '0', '0')
# ('nm3557427', 'Lon Waitman', '0', '0')
# ('nm3557493', 'Natalya Pakhomova', '0', '0')
# ('nm3557527', 'Ilan Mester', '0', '0')
# ('nm3557535', 'Daniel K. Smith', '0', '0')
# ('nm3557578', 'Aniruddha Pande', '0', '0')
# ('nm3557581', 'Mamen del Castillo', '0', '0')
# ('nm3557594', 'Olga Simonova', '0', '0')
# ('nm3557600', 'Jason Hamilton', '0', '0')
# ('nm3557616', 'Dimitris Kotselis', '0', '0')
# ('nm3557623', 'Jeff Sherfey', '0', '0')
# ('nm3557636', 'Matthew Levenstein', '0', '0')
# ('nm3557640', 'Matt Berlin', '0', '0')
# ('nm3557643', "Hadiyo Jim'Ale", '0', '0')
# ('nm3557689', 'Afdhere Jama', '1980', '0')
# ('nm3557692', 'Charlotte Erlih', '0', '0')
# ('nm3557693', 'Nily Refai', '0', '0')
# ('nm3557704', 'Karl Ebert', '0', '0')
# ('nm3557719', 'Phil Clarke Jr.', '0', '0')
# ('nm3557720', 'Sergio de Miguel', '0', '0')
# ('nm3557721', 'Bruno Lochuarn', '0', '0')
# ('nm3557725', 'Yoann Gromb', '0', '0')
# ('nm3557741', 'Jeremy Brull', '0', '0')
# ('nm3557767', 'Kawal Soni', '0', '0')
# ('nm3557788', 'Karim Tabbaa', '0', '0')
# ('nm3557826', 'Jason Berry', '0', '0')
# ('nm3557854', "Patrick O'Sullivan", '0', '0')
# ('nm3557912', 'Tom Peirce', '0', '0')
# ('nm3557919', 'Lakshmi Indrasimhan', '0', '0')
# ('nm3557929', 'Mark Ross Smith', '0', '0')
# ('nm3557963', 'Barnaba Bonati', '0', '0')
# ('nm3558041', 'Greg Lejnieks', '0', '0')
# ('nm3558050', 'Brandan Alan McConnaughhay', '0', '0')
# ('nm3558063', 'Richard Thompson', '1986', '0')
# ('nm3558065', 'Jason Johnson', '0', '0')
# ('nm3558077', 'Béla Baptiste', '0', '0')
# ('nm3558081', 'Mohammad Mehdi Omidvari', '0', '0')
# ('nm3558108', 'Maylis De Kerangal', '0', '0')
# ('nm3558130', 'Emel Tulgar', '0', '0')
# ('nm3558153', 'Mario Hinse', '0', '0')
# ('nm3558156', 'David Arthur', '0', '0')
# ('nm3558173', 'Juan Carlos Martín Torres', '0', '0')
# ('nm3558188', 'Gabriel Lopez', '0', '0')
# ('nm3558198', 'Jae-Woo Kim', '0', '0')
# ('nm3558214', 'Wei-Jan Liu', '0', '0')
# ('nm3558218', 'Sébastien Dacek', '0', '0')
# ('nm3558222', 'Rebecca K. Olivia', '0', '0')
# ('nm3558223', 'Todd Lejnieks', '0', '0')
# ('nm3558233', 'Michael K. Winder', '0', '0')
# ('nm3558263', 'Gilles Paillet', '0', '0')
# ('nm3558297', 'Indrajit Nattoji', '0', '0')
# ('nm3558303', 'Florian M. Beierl', '0', '0')
# ('nm3558321', 'Concha Calvo', '0', '0')
# ('nm3558331', 'Erica Saleh', '0', '0')
# ('nm3558345', 'Doug Hawley', '0', '0')
# ('nm3558356', 'Helen Le Han', '0', '0')
# ('nm3558363', 'Sheila Callaghan', '0', '0')
# ('nm3558365', 'Chloé Chevalier', '0', '0')
# ('nm3558395', 'Lauren Valentine', '1984', '0')
# ('nm3558400', 'Helena Raposo', '0', '0')
# ('nm3558500', 'Josu Ortiz Aguirre', '0', '0')
# ('nm3558509', 'Christy Leonardo', '0', '0')
# ('nm3558517', 'Maria Arnell', '0', '0')
# ('nm3558555', 'Phoebe Leonard', '0', '0')
# ('nm3558561', 'Robin Das', '1963', '0')
# ('nm3558563', 'Matt Herrmann', '0', '0')
# ('nm3558564', 'Tom Service', '0', '0')
# ('nm3558578', 'Jenny Connell', '0', '0')
# ('nm3558581', 'Jeff Fong', '0', '0')
# ('nm3558582', 'Daniel Havas', '0', '0')
# ('nm3558605', 'Ethan Karson', '0', '0')
# ('nm3558606', 'Miia Tervo', '0', '0')
# ('nm3558625', 'Kirk Lake', '0', '0')
# ('nm3558631', 'Heath Tait', '0', '0')
# ('nm3558636', 'David B.', '0', '0')
# ('nm3558677', 'Jesse Mccarthy', '0', '0')
# ('nm3558684', 'Hannes Baumgartner', '0', '0')
# ('nm3558690', 'Daniel Zimmermann', '0', '0')
# ('nm3558725', 'Shira Florentin', '0', '0')
# ('nm3558742', 'Shane Johnson', '0', '0')
# ('nm3558764', 'Claudia Lage', '0', '0')
# ('nm3558796', 'Anuj Kapoor', '0', '0')
# ('nm3558803', 'Isabelle Robert', '0', '0')
# ('nm3558807', 'Rick Archbold', '0', '0')
# ('nm3558824', 'Alwyn Dale', '0', '0')
# ('nm3558844', 'Natalia Serna', '0', '0')
# ('nm3558845', 'Ernest Hollingsworth', '0', '0')
# ('nm3558859', 'Gal Greenspan', '0', '0')
# ('nm3558860', 'Waseem Shaikh', '0', '0')
# ('nm3558870', 'Cary Wolinsky', '0', '0')
# ('nm3558871', 'Hannes Hoberg', '0', '0')
# ('nm3558884', 'Matthew Krouse', '0', '0')
# ('nm3558893', 'Felipe Matilla', '0', '0')
# ('nm3558917', 'Nicholas Miers', '0', '0')
# ('nm3558926', 'Pamela Casey', '0', '0')
# ('nm3558930', 'Jeffrey Sullivan', '0', '0')
# ('nm3558945', 'Baron Norris', '0', '0')
# ('nm3559020', 'Arnold Gillespie', '0', '0')
# ('nm3559040', 'Makoto Koyama', '0', '0')
# ('nm3559058', 'Russ Bolinger', '0', '0')
# ('nm3559110', 'Antoinette Anders', '0', '0')
# ('nm3559149', 'Louis Yuen', '0', '0')
# ('nm3559157', 'Theo Kling', '0', '0')
# ('nm3559189', 'Berenika Bailey', '0', '2020')
# ('nm3559194', 'Rod Zielinski', '0', '0')
# ('nm3559229', 'Lauri Cederlund', '0', '0')
# ('nm3559233', 'Geneviève Brisac', '0', '0')
# ('nm3559244', 'Allison Becker', '0', '0')
# ('nm3559249', 'Nick Lane', '0', '0')
# ('nm3559280', 'Anneli Rautiainen', '0', '0')
# ('nm3559291', 'James Collins', '0', '0')
# ('nm3559321', 'Renee Glover', '0', '0')
# ('nm3559337', 'Jeremias Segovia', '0', '0')
# ('nm3559357', 'Lyla Storm', '1989', '0')
# ('nm3559362', 'Chad Overman', '0', '0')
# ('nm3559401', 'Tatiana Almeida', '0', '0')
# ('nm3559457', 'Federica Cellini', '0', '0')
# ('nm3559465', 'Corey Williams', '1978', '0')
# ('nm3559500', 'Rick Remender', '0', '0')
# ('nm3559520', 'Gary Gray', '0', '0')
# ('nm3559532', 'Andrew Kole', '0', '0')
# ('nm3559560', 'Mia Falcon', '0', '0')
# ('nm3559563', 'Waldir Leite', '0', '0')
# ('nm3559567', 'Julio Roman', '0', '0')
# ('nm3559573', 'Antonio Naranjo', '0', '0')
# ('nm3559584', 'Ming Liu', '0', '0')
# ('nm3559600', 'Simone Russo', '0', '0')
# ('nm3559611', 'Xing Zi', '0', '0')
# ('nm3559616', 'Nora Stirling', '0', '0')
# ('nm3559621', 'Aric Hartvig', '0', '0')
# ('nm3559637', 'Paul Schuler', '0', '0')
# ('nm3559651', 'Michal Zelenka', '0', '0')
# ('nm3559656', 'Leanne James', '0', '0')
# ('nm3559662', 'Heather Feinberg', '0', '0')
# ('nm3559666', 'Cale Tompkins', '0', '0')
# ('nm3559732', 'Michael Glennon', '0', '0')
# ('nm3559752', 'Paul Hilborn', '0', '0')
# ('nm3559764', 'Candice Cruz', '0', '0')
# ('nm3559783', 'Will Bakke', '0', '0')
# ('nm3559804', 'Noel Evans', '0', '0')
# ('nm3559826', 'Jamie Lerman', '0', '0')
# ('nm3559842', 'Stephen Nigro', '0', '0')
# ('nm3559843', 'William Best', '1982', '0')
# ('nm3559855', 'Simon Dymond', '0', '0')
# ('nm3559882', 'Scott Northrup', '0', '0')
# ('nm3559884', 'Meghan Seidel', '0', '0')
# ('nm3559895', 'Dee Wills', '0', '0')
# ('nm3559939', 'Caitlin Brandes', '0', '0')
# ('nm3559946', 'Lars Edman', '0', '0')
# ('nm3559949', 'Tracy Faisal', '0', '0')
# ('nm3559955', 'Ramona Bergmann', '0', '0')
# ('nm3559969', 'Lares Feliciano', '0', '0')
# ('nm3559994', 'Esko Peltola', '0', '0')
# ('nm3560004', 'Yoav Katz', '0', '0')
# ('nm3560026', 'Matt Thorne', '0', '0')
# ('nm3560064', 'Emily Haddad', '0', '0')
# ('nm3560070', 'Alan Fischer', '0', '0')
# ('nm3560074', 'Kevin Brass', '0', '0')
# ('nm3560085', 'Ilkka Sjöman', '0', '0')
# ('nm3560087', 'Trent Coffin', '0', '0')
# ('nm3560106', 'Kylie Skelton', '0', '0')
# ('nm3560112', 'Nitzan Ron', '0', '0')
# ('nm3560119', 'Danielle Zorbas', '0', '0')
# ('nm3560128', 'Les Hemstock', '0', '0')
# ('nm3560141', 'Ryan Guenther', '0', '0')
# ('nm3560145', 'Les Branson', '0', '0')
# ('nm3560146', 'Alexandre Leborgne', '0', '0')
# ('nm3560164', 'Grant Monk', '0', '0')
# ('nm3560171', 'Philippe Bourret', '0', '0')
# ('nm3560172', 'Mo Faisal', '0', '0')
# ('nm3560173', 'Ina Kraus', '0', '0')
# ('nm3560178', 'Gabe Kuchar', '0', '0')
# ('nm3560181', 'Satomi M. Martin', '0', '0')
# ('nm3560195', 'Jay New', '0', '0')
# ('nm3560202', 'Laurence Timmons', '0', '0')
# ('nm3560206', 'Milan Tomic', '0', '0')
# ('nm3560218', 'Ryan Barney', '0', '0')
# ('nm3560229', 'Dan Marro', '0', '0')
# ('nm3560232', 'Mohit Ray', '0', '0')
# ('nm3560241', 'Zach Meiners', '0', '0')
# ('nm3560244', 'James Elson', '0', '0')
# ('nm3560254', 'Brandon Mattingly', '0', '0')
# ('nm3560278', 'Madeline Henry', '0', '0')
# ('nm3560297', 'Asaf Mann', '0', '0')
# ('nm3560301', 'Ajay Mohanty', '0', '0')
# ('nm3560337', 'Jesse Pattison', '0', '0')
# ('nm3560354', 'Lee Copeland', '0', '0')
# ('nm3560361', 'Alexander Deleon', '0', '0')
# ('nm3560363', 'Max Lance', '0', '0')
# ('nm3560365', 'Max Cook', '0', '0')
# ('nm3560371', 'Marc de Chauveron', '0', '0')
# ('nm3560372', 'Hande Vural', '0', '0')
# ('nm3560377', 'Griffin Patrick Post', '0', '0')
# ('nm3560388', 'Vincent Ethier', '0', '0')
# ('nm3560390', 'Tracy Lucca', '0', '0')
# ('nm3560392', 'Anamika Bandopadhyay', '0', '0')
# ('nm3560396', 'Beba Slijepcevic', '0', '0')
# ('nm3560439', 'Philippe Lupien', '1986', '0')
# ('nm3560448', 'Ricardo Presas', '0', '0')
# ('nm3560452', 'Kai Lehtonen', '0', '0')
# ('nm3560478', 'Shiri Kleinman', '0', '0')
# ('nm3560486', 'Bobby Blood', '0', '0')
# ('nm3560495', 'Amar Shah', '0', '0')
# ('nm3560511', 'Thomas Devereaux', '0', '0')
# ('nm3560512', 'Ben Katagiri', '0', '0')
# ('nm3560541', 'Rose Person', '0', '0')
# ('nm3560559', 'Rubin Stein', '1982', '0')
# ('nm3560585', 'Mary Camarena', '0', '0')
# ('nm3560614', 'Jeff Daly', '0', '0')
# ('nm3560621', 'Melanie Fiona', '1983', '0')
# ('nm3560626', 'Ventura Montoya', '0', '0')
# ('nm3560629', 'Carlo Bonini', '1967', '0')
# ('nm3560633', 'Cristiano Gerbino', '0', '0')
# ('nm3560637', 'John Englander', '0', '0')
# ('nm3560639', 'Alex Haughey', '0', '0')
# ('nm3560703', 'Donny Sheldon', '0', '0')
# ('nm3560742', 'Tonatiuh Moreno', '0', '0')
# ('nm3560768', 'Yves Goulart', '1975', '0')
# ('nm3560773', 'Nita Eden So', '0', '0')
# ('nm3560839', 'Anson Kessinger', '0', '0')
# ('nm3560860', 'Zoltán Bogdán', '0', '0')
# ('nm3560861', 'Spike Carpenter', '0', '0')
# ('nm3560865', 'Silvana Magnoni', '0', '0')
# ('nm3560885', 'Yumi Suzuki', '0', '0')
# ('nm3560968', 'Gareth Jones', '0', '0')
# ('nm3560996', 'Cesar Sodero', '0', '0')
# ('nm3561018', 'Eleonoro Fiorini', '0', '0')
# ('nm3561020', 'Ana Lydia Monaco', '0', '0')
# ('nm3561086', 'Owen Locke', '0', '0')
# ('nm3561087', 'Richard E. Davis', '0', '0')
# ('nm3561109', 'Man-hung Poon', '0', '0')
# ('nm3561139', 'Robert Kalvar', '0', '0')
# ('nm3561140', 'Jeremy Morris-Burke', '0', '0')
# ('nm3561163', 'Elizabeth Rodriguez', '0', '0')
# ('nm3561195', 'William H. Murray', '0', '0')
# ('nm3561215', 'Lenka Somolova', '0', '0')
# ('nm3561221', 'Dave Douglas', '0', '0')
# ('nm3561228', 'Justin B. Turner', '0', '0')
# ('nm3561234', 'Michael Vincent', '0', '0')
# ('nm3561236', 'Francesca Pansarella', '0', '0')
# ('nm3561300', 'Christina Marie Diaz', '0', '0')
# ('nm3561303', 'Christopher W. Graham', '0', '0')
# ('nm3561307', 'Nadia Ickx', '0', '0')
# ('nm3561333', 'Kuzuryu', '0', '0')
# ('nm3561371', 'Karen Ross', '0', '0')
# ('nm3561379', 'Kouemo Auguste Bernard', '0', '0')
# ('nm3561397', 'Johannes Bucher', '0', '0')
# ('nm3561403', 'Grégoire de Tours', '0', '0')
# ('nm3561408', 'Bret Kerven', '0', '0')
# ('nm3561409', 'Nick Irons', '0', '0')
# ('nm3561419', 'Janice Jarzabek', '0', '0')
# ('nm3561424', 'Josef Bielen', '0', '0')
# ('nm3561432', 'Myke Holmes', '0', '0')
# ('nm3561438', 'Anna Rizk', '0', '0')
# ('nm3561484', 'Mo Thevenet', '0', '0')
# ('nm3561486', 'Richard Pecha', '0', '0')
# ('nm3561493', 'Stefanie Y. Hong', '0', '0')
# ('nm3561496', 'Hsin-Yi Tu', '0', '0')
# ('nm3561514', 'Kyle Yaschuk', '0', '0')
# ('nm3561541', 'Weikang Chou', '0', '0')
# ('nm3561567', 'Justin Nordell', '1986', '0')
# ('nm3561575', 'Nelinda Palomino', '0', '0')
# ('nm3561583', 'Cory Feezer', '0', '0')
# ('nm3561634', 'Ólafur Hannesson', '1985', '0')
# ('nm3561636', 'J. Starr Welty', '0', '0')
# ('nm3561639', 'Bryan Turnage', '0', '0')
# ('nm3561646', 'Andrea Zuliani', '0', '0')
# ('nm3561656', 'Jonathan Parrish', '0', '0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-187d5e08e695> in <module>
#      16         print(data)
#      17         curs.execute(sql,data)
# ---> 18         conn.commit()
#      19
#      20 f.close()
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pymysql\connections.py in commit(self)
#     468         """
#     469         self._execute_command(COMMAND.COM_QUERY, "COMMIT")
# --> 470         self._read_ok_packet()
#     471
#     472     def rollback(self):
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pymysql\connections.py in _read_ok_packet(self)
#     441
#     442     def _read_ok_packet(self):
# --> 443         pkt = self._read_packet()
#     444         if not pkt.is_ok_packet():
#     445             raise err.OperationalError(2014, "Command Out of Sync")
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     690         buff = bytearray()
#     691         while True:
# --> 692             packet_header = self._read_bytes(4)
#     693             # if DEBUG: dump_packet(packet_header)
#     694
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pymysql\connections.py in _read_bytes(self, num_bytes)
#     730         while True:
#     731             try:
# --> 732                 data = self._rfile.read(num_bytes)
#     733                 break
#     734             except (IOError, OSError) as e:
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:
